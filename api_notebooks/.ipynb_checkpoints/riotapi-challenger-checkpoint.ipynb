# %%
#imports

# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import time
import requests
import bs4
import json
from requests.auth import HTTPBasicAuth
from flatten_json import flatten

# %%
# 20 requests every 1 seconds(s)
# 100 requests every 2 minutes(s)

apikey = "RGAPI-d2088fc5-5f70-4703-8360-03eabf53dcca"

# %%
# get challenger summonerId from league-exp-api
# 1.2 delay bc short list

req = requests.get("https://na1.api.riotgames.com/lol/league-exp/v4/entries/RANKED_SOLO_5x5/CHALLENGER/I?page=1&api_key={}"
                   .format(apikey),time.sleep(1.2))
assert req.status_code == 200
data = req.json()
sumids = [d['summonerId'] for d in data]

# %%
# get accountId via summonerId via summoner-api
# 1.2 delay bc short list

accids = []
for sumid in sumids:
    sumreq = requests.get("https://na1.api.riotgames.com/lol/summoner/v4/summoners/{}?api_key={}"
                          .format(sumid,apikey),time.sleep(1.2))
    assert sumreq.status_code == 200
    accids.append(sumreq.json()['accountId'])

# %%
# get game ids from match history via match-api
# 1.3 delay bc long list

gamids = []

for acc in accids:
    matlreq = requests.get("https://na1.api.riotgames.com/lol/match/v4/matchlists/by-account/{}?api_key={}"
                           .format(acc,apikey),time.sleep(1.3))
    assert matlreq.status_code == 200
    gamids += [d['gameId'] for d in matlreq.json()['matches']]

# %%
# print original length, then correct overlap from shared games and print new length

print(len(gamids))

gamids = set(gamids)

print(len(gamids))
# Out:
# 10465
# 10465

# %%
# get individual match information from gamids list via match-api
# 1.5 delay bc long list and repeated issues with 

matchlist = []

for gam in gamids:
    gamreq = requests.get("https://na1.api.riotgames.com/lol/match/v4/matches/{}?api_key={}"
                          .format(gam,apikey),time.sleep(1.5))
    assert gamreq.status_code == 200
    match = flatten(gamreq.json())
    matchlist.append(match)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-18-dc60281b70af> in <module>
#       7     gamreq = requests.get("https://na1.api.riotgames.com/lol/match/v4/matches/{}?api_key={}"
#       8                           .format(gam,apikey),time.sleep(1.3))
# ----> 9     assert gamreq.status_code == 200
#      10     match = flatten(gamreq.json())
#      11     matchlist.append(match)
#
# AssertionError:

# %%
gamreq.status_code
# Out:
# 504

# %%
# check length of matchlist 

check = [len(m) for m in matchlist]
len(matchlist),max(check),min(check)
# Out:
# (515, 1550, 1211)

# %%
# create df from matches

df = pd.DataFrame(matchlist)

# %%
df
# Out:
#          gameId platformId   gameCreation  gameDuration  queueId  mapId  \
# 0    3491201028        NA1  1594516442702          1624      450     12
# 1    3425927177        NA1  1589811429884          1548      420     11
# 2    3463315468        NA1  1592285561264          1499      420     11
# 3    3490775054        NA1  1594487307024          2300      420     11
# 4    3449782290        NA1  1591330333433          1413      420     11
# ..          ...        ...            ...           ...      ...    ...
# 510  3485894080        NA1  1594110127570          2040      420     11
# 511  3486123456        NA1  1594143902472          1533      450     12
# 512  3439101379        NA1  1590635004844          1432      420     11
# 513  3479111108        NA1  1593554707755          2055      420     11
# 514  3482944962        NA1  1593865240398          1021      420     11
#
#      seasonId     gameVersion gameMode      gameType  ...  \
# 0          13  10.14.327.8505     ARAM  MATCHED_GAME  ...
# 1          13  10.10.320.3039  CLASSIC  MATCHED_GAME  ...
# 2          13  10.12.324.5925  CLASSIC  MATCHED_GAME  ...
# 3          13  10.14.327.8505  CLASSIC  MATCHED_GAME  ...
# 4          13  10.11.322.2991  CLASSIC  MATCHED_GAME  ...
# ..        ...             ...      ...           ...  ...
# 510        13  10.13.326.4870  CLASSIC  MATCHED_GAME  ...
# 511        13  10.13.326.4870     ARAM  MATCHED_GAME  ...
# 512        13  10.10.320.3039  CLASSIC  MATCHED_GAME  ...
# 513        13  10.13.326.4870  CLASSIC  MATCHED_GAME  ...
# 514        13  10.13.326.4870  CLASSIC  MATCHED_GAME  ...
#
#      participants_5_timeline_xpDiffPerMinDeltas_30-end  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
#
#     participants_5_timeline_xpDiffPerMinDeltas_20-30  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 510                                              NaN
# 511                                              NaN
# 512                                              NaN
# 513                                          -120.25
# 514                                              NaN
#
#      participants_5_timeline_damageTakenDiffPerMinDeltas_30-end  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
#
#      participants_5_timeline_damageTakenDiffPerMinDeltas_20-30  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                              168.0
# 514                                                NaN
#
#      participants_9_timeline_csDiffPerMinDeltas_30-end  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
#
#      participants_9_timeline_csDiffPerMinDeltas_20-30  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 510                                              0.65
# 511                                               NaN
# 512                                               NaN
# 513                                             -0.05
# 514                                               NaN
#
#      participants_9_timeline_xpDiffPerMinDeltas_30-end  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
#
#      participants_9_timeline_xpDiffPerMinDeltas_20-30  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 510                                           -127.60
# 511                                               NaN
# 512                                               NaN
# 513                                           -120.25
# 514                                               NaN
#
#      participants_9_timeline_damageTakenDiffPerMinDeltas_30-end  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
#
#      participants_9_timeline_damageTakenDiffPerMinDeltas_20-30
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 510                                             -55.65
# 511                                                NaN
# 512                                                NaN
# 513                                             168.00
# 514                                                NaN
#
# [515 rows x 1552 columns]
