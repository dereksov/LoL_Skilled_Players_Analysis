# %%
#imports

# %matplotlib inline
import pandas as pd
import numpy as np
import time
import requests
import bs4
import json
from flatten_json import flatten

# %%
# 20 requests every 1 seconds(s)
# 100 requests every 2 minutes(s)

apikey = "RGAPI-502fbac9-234f-47fc-b37e-23b74ef563b0"

# %%
# get challenger summonerId from league-exp-api
# 1.2 delay bc short list

req = requests.get("https://euw1.api.riotgames.com/lol/league-exp/v4/entries/RANKED_SOLO_5x5/MASTER/I?page=1&api_key={}"
                   .format(apikey),time.sleep(1.2))
assert req.status_code == 200
data = req.json()
sumids = [d['summonerId'] for d in data]

# %%
sumids[0:5]
# Out:
# ['ne2x4D9Iw2seal8TL0XQCTNmWleBZKlfS93s33128QinNfM',
#  '7yo0fGP6cYQRlxdlunvQwFzK5HXsMi2XzVkAuuMbQQRB6hY',
#  'MsE5_TjrZ3xQMNv6RnY779vGUIPEZOUu2duYTrL1Nwche2Gv',
#  'FbUPULPW4KvVhtxmbbAVHiVufeu14nEtx0FXK3wnbkPLu0I',
#  'qyPpX6oCAQiEnEFAU_RpGJOPvhz8sBLrI5iFwWCloibxenc']

# %%
# get accountId via summonerId via summoner-api
# 1.2 delay bc short list

accids = []
for sumid in sumids:
    sumreq = requests.get("https://euw1.api.riotgames.com/lol/summoner/v4/summoners/{}?api_key={}"
                          .format(sumid,apikey),time.sleep(1.2))
    assert sumreq.status_code == 200
    accids.append(sumreq.json()['accountId'])

# %%
# get game ids from match history via match-api
# 1.3 delay bc long list

gamids = []

for acc in accids:
    matlreq = requests.get("https://euw1.api.riotgames.com/lol/match/v4/matchlists/by-account/{}?api_key={}"
                           .format(acc,apikey),time.sleep(1.3))
    assert matlreq.status_code == 200
    gamids += [d['gameId'] for d in matlreq.json()['matches']]

# %%
# print original length, then correct overlap from shared games and print new length

print(len(gamids))

gamids = set(gamids)

print(len(gamids))
# Out:
# 20500
# 17771

# %%
with open('euw_chall_gam_id_list.txt', 'r') as f:
    challgames = f.read().splitlines()

# %%
challgames =set([int(e) for e in challgames])

# %%
with open('gm_gam_id_list.txt', 'r') as f:
    gmgames = f.read().splitlines()

# %%
gmgames =set([int(e) for e in gmgames])

# %%
gamids = gamids - (gamids & (gmgames | challgames))

# %%
# get individual match information from gamids list via match-api
# 1.5 delay bc long list and repeated issues with 

matchlist = []

for gam in gamids:
    gamreq = requests.get("https://na1.api.riotgames.com/lol/match/v4/matches/{}?api_key={}"
                          .format(gam,apikey),time.sleep(1.3))
    
    i=0
    while gamreq.status_code != 200:
        gamreq = requests.get("https://na1.api.riotgames.com/lol/match/v4/matches/{}?api_key={}"
                          .format(gam,apikey),time.sleep(1.3))
        i+=1
        if i == 5:
            break
            
    match = flatten(gamreq.json())
    matchlist.append(match)

# %%
gamreq.status_code
# Out:
# 200

# %%
# check length of matchlist 

check = [len(m) for m in matchlist]
len(matchlist),max(check),min(check)
# Out:
# (14811, 1557, 2)

# %%
# create df from matches

df = pd.DataFrame(matchlist)

# %%
df = df[df['gameMode'] == 'CLASSIC']

# %%
df
# Out:
#              gameId platformId  gameCreation  gameDuration  queueId  mapId  \
# 0      3.470590e+09        NA1  1.592863e+12        1921.0    420.0   11.0
# 1      3.464954e+09        NA1  1.592421e+12        1410.0    420.0   11.0
# 2      3.477275e+09        NA1  1.593402e+12        1261.0    420.0   11.0
# 3      3.477471e+09        NA1  1.593414e+12        1983.0    440.0   11.0
# 6      3.457286e+09        NA1  1.591843e+12        1430.0    420.0   11.0
# ...             ...        ...           ...           ...      ...    ...
# 14806  3.487564e+09        NA1  1.594224e+12        1549.0    420.0   11.0
# 14807  3.480158e+09        NA1  1.593634e+12         762.0    420.0   11.0
# 14808  3.326738e+09        NA1  1.584386e+12        1407.0    420.0   11.0
# 14809  3.479175e+09        NA1  1.593562e+12        2128.0    420.0   11.0
# 14810  3.310223e+09        NA1  1.582941e+12        1172.0    420.0   11.0
#
#        seasonId     gameVersion gameMode      gameType  ...  \
# 0          13.0  10.12.325.6222  CLASSIC  MATCHED_GAME  ...
# 1          13.0  10.12.324.5925  CLASSIC  MATCHED_GAME  ...
# 2          13.0  10.13.326.4870  CLASSIC  MATCHED_GAME  ...
# 3          13.0  10.13.326.4870  CLASSIC  MATCHED_GAME  ...
# 6          13.0  10.12.323.8771  CLASSIC  MATCHED_GAME  ...
# ...         ...             ...      ...           ...  ...
# 14806      13.0  10.14.327.1684  CLASSIC  MATCHED_GAME  ...
# 14807      13.0  10.13.326.4870  CLASSIC  MATCHED_GAME  ...
# 14808      13.0    10.5.312.392  CLASSIC  MATCHED_GAME  ...
# 14809      13.0  10.13.326.4870  CLASSIC  MATCHED_GAME  ...
# 14810      13.0   10.4.308.9400  CLASSIC  MATCHED_GAME  ...
#
#        participants_1_highestAchievedSeasonTier  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 6                                           NaN
# ...                                         ...
# 14806                                       NaN
# 14807                                       NaN
# 14808                                       NaN
# 14809                                       NaN
# 14810                                       NaN
#
#       participants_2_highestAchievedSeasonTier  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 6                                          NaN
# ...                                        ...
# 14806                                      NaN
# 14807                                      NaN
# 14808                                      NaN
# 14809                                      NaN
# 14810                                      NaN
#
#       participants_3_highestAchievedSeasonTier  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 6                                          NaN
# ...                                        ...
# 14806                                      NaN
# 14807                                      NaN
# 14808                                      NaN
# 14809                                      NaN
# 14810                                      NaN
#
#       participants_4_highestAchievedSeasonTier  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 6                                          NaN
# ...                                        ...
# 14806                                      NaN
# 14807                                      NaN
# 14808                                      NaN
# 14809                                      NaN
# 14810                                      NaN
#
#       participants_5_highestAchievedSeasonTier  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 6                                          NaN
# ...                                        ...
# 14806                                      NaN
# 14807                                      NaN
# 14808                                      NaN
# 14809                                      NaN
# 14810                                      NaN
#
#       participants_6_highestAchievedSeasonTier  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 6                                          NaN
# ...                                        ...
# 14806                                      NaN
# 14807                                      NaN
# 14808                                      NaN
# 14809                                      NaN
# 14810                                      NaN
#
#       participants_8_highestAchievedSeasonTier  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 6                                          NaN
# ...                                        ...
# 14806                                      NaN
# 14807                                      NaN
# 14808                                      NaN
# 14809                                      NaN
# 14810                                      NaN
#
#       participants_9_highestAchievedSeasonTier  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 6                                          NaN
# ...                                        ...
# 14806                                      NaN
# 14807                                      NaN
# 14808                                      NaN
# 14809                                      NaN
# 14810                                      NaN
#
#        participants_7_highestAchievedSeasonTier  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 6                                           NaN
# ...                                         ...
# 14806                                       NaN
# 14807                                       NaN
# 14808                                       NaN
# 14809                                       NaN
# 14810                                       NaN
#
#        participants_0_highestAchievedSeasonTier
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 6                                           NaN
# ...                                         ...
# 14806                                       NaN
# 14807                                       NaN
# 14808                                       NaN
# 14809                                       NaN
# 14810                                       NaN
#
# [12617 rows x 1564 columns]

# %%
len(set(list(df['gameId'])))
# Out:
# 12617

# %%
compression_opts = dict(method='zip',
                        archive_name='master.csv')

# %%
df.to_csv('master.zip', index=False,
          compression=compression_opts)

# %%
df['gameId'].astype(str).str.split(".").str[0].astype()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-25aebd7ebb64> in <module>
# ----> 1 df['gameId'].astype(str).str.split(".").str[0].astype(long)
#
# NameError: name 'long' is not defined

# %%
masgames = list(df['gameId'])
masgames
# Out:
# [3470589956.0,
#  3464953863.0,
#  3477274631.0,
#  3477471253.0,
#  3457286173.0,
#  3487957034.0,
#  3488743468.0,
#  3425042489.0,
#  3500277820.0,
#  3416391746.0,
#  3478650952.0,
#  3477930058.0,
#  3477864532.0,
#  3490185305.0,
#  3486777435.0,
#  3475177570.0,
#  3494707307.0,
#  3487694960.0,
#  3464691839.0,
#  3402694784.0,
#  3482452099.0,
#  3498246306.0,
#  3488874664.0,
#  3490513066.0,
#  3484025020.0,
#  3474456769.0,
#  3486908618.0,
#  3499753675.0,
#  3494510809.0,
#  3458007262.0,
#  3435987170.0,
#  3436183779.0,
#  3485532393.0,
#  3489071344.0,
#  3468820730.0,
#  3420389632.0,
#  3495166210.0,
#  3488743683.0,
#  3473473800.0,
#  3497328914.0,
#  3462988052.0,
#  3498639637.0,
#  3492479255.0,
#  3331981597.0,
#  3409772830.0,
#  3475767586.0,
#  3471704375.0,
#  3484680507.0,
#  3484877133.0,
#  3329687898.0,
#  3495887204.0,
#  3494904168.0,
#  3470917994.0,
#  3490906475.0,
#  3500212588.0,
#  3498377582.0,
#  3246260594.0,
#  3495756149.0,
#  3498574211.0,
#  3488678280.0,
#  3499491727.0,
#  3415343505.0,
#  3492151702.0,
#  3455844759.0,
#  3444244890.0,
#  3346399643.0,
#  3401187740.0,
#  3495100834.0,
#  3490120098.0,
#  3471901093.0,
#  3441951142.0,
#  3493396905.0,
#  3487695279.0,
#  3496280503.0,
#  3462070713.0,
#  3484418491.0,
#  3446211006.0,
#  3496346057.0,
#  3483435466.0,
#  3399025099.0,
#  3494838735.0,
#  3471573462.0,
#  3490447835.0,
#  3376480736.0,
#  3467903456.0,
#  3495559656.0,
#  3471049196.0,
#  3408790007.0,
#  3484484089.0,
#  3485401596.0,
#  3494052349.0,
#  3458466313.0,
#  3497132553.0,
#  3487629838.0,
#  3483107864.0,
#  3487695392.0,
#  3451847204.0,
#  3487567969.0,
#  3491893353.0,
#  3468103787.0,
#  3431272572.0,
#  3496284290.0,
#  3477803138.0,
#  3495366788.0,
#  3438219399.0,
#  3484684424.0,
#  3471380617.0,
#  3436974217.0,
#  3480096907.0,
#  3487895694.0,
#  3459453073.0,
#  3487764637.0,
#  3494908063.0,
#  3487764640.0,
#  3410104484.0,
#  3477016746.0,
#  3493335212.0,
#  3425833134.0,
#  3267760313.0,
#  3460370628.0,
#  3494187209.0,
#  3457814738.0,
#  3487633618.0,
#  3496743151.0,
#  3482915059.0,
#  3483373818.0,
#  3501134078.0,
#  3457880331.0,
#  3312521487.0,
#  3452047631.0,
#  3499954460.0,
#  3495891231.0,
#  3450802467.0,
#  3463450926.0,
#  3478589744.0,
#  3500347697.0,
#  3497005367.0,
#  3469480252.0,
#  3432517951.0,
#  3433632070.0,
#  3499561296.0,
#  3480228195.0,
#  3445297510.0,
#  3487633771.0,
#  3475050859.0,
#  3448115574.0,
#  3368620408.0,
#  3498250617.0,
#  3498185088.0,
#  3488027015.0,
#  3480097160.0,
#  3487830409.0,
#  3469283726.0,
#  3490189712.0,
#  3464302992.0,
#  3473412501.0,
#  3485274519.0,
#  3478327707.0,
#  3496939945.0,
#  3462074796.0,
#  3485340081.0,
#  3496087997.0,
#  3494449605.0,
#  3489468875.0,
#  3488027084.0,
#  3451982287.0,
#  3440775644.0,
#  3493597670.0,
#  3493401063.0,
#  3428848112.0,
#  3486519792.0,
#  3312128499.0,
#  3484881397.0,
#  3476296182.0,
#  3478852087.0,
#  3488682492.0,
#  3464237565.0,
#  3467252223.0,
#  3496612351.0,
#  3474788874.0,
#  3482259986.0,
#  3490845204.0,
#  3497267733.0,
#  3367440918.0,
#  3483374103.0,
#  3488616988.0,
#  3484488226.0,
#  3493204516.0,
#  3440316967.0,
#  3488748075.0,
#  3481539120.0,
#  3494122035.0,
#  3496284728.0,
#  3493007930.0,
#  3496612414.0,
#  3422229054.0,
#  3308196416.0,
#  3491107393.0,
#  3498054212.0,
#  3440710216.0,
#  3463713362.0,
#  3473609305.0,
#  3479048800.0,
#  3466400355.0,
#  3485340270.0,
#  3498971765.0,
#  3388740217.0,
#  3459519104.0,
#  3478524556.0,
#  3492549270.0,
#  3489141403.0,
#  3480162974.0,
#  3466597024.0,
#  3472560803.0,
#  3469677223.0,
#  3388543663.0,
#  3497857711.0,
#  3484029619.0,
#  3497267893.0,
#  3473543862.0,
#  3498578623.0,
#  3463713484.0,
#  3326612176.0,
#  3473281744.0,
#  3213169362.0,
#  3460436705.0,
#  3460436708.0,
#  3485930231.0,
#  3477934844.0,
#  3477934845.0,
#  3469218568.0,
#  3447591688.0,
#  3413578507.0,
#  3495432980.0,
#  3364623130.0,
#  3495367454.0,
#  3487634206.0,
#  3465351971.0,
#  3494712103.0,
#  3423605547.0,
#  3501200181.0,
#  3492746051.0,
#  3494581067.0,
#  ...]

# %%
with open('mas_gam_id_list.txt', 'w') as f:
    for item in masgames:
        f.write("%s\n" % item)
