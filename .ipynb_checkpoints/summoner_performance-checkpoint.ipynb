# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf   
## if error: python3.6 -m pip install scipy==1.2 --upgrade
import json 
import pprint
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import plotly.express as px

# %%
stats = pd.read_csv('data/average_stats.zip', compression = 'zip')

# %%
stats.head()
# Out:
#    stats_champLevel  stats_perk4Var1  stats_perkPrimaryStyle  stats_kills  \
# 0         14.333333         6.000000             8200.000000     5.666667
# 1         12.000000        20.000000             8100.000000     2.000000
# 2         13.272727       777.659091             8091.477273     6.159091
# 3         12.111111      3459.777778             8218.518519     1.703704
# 4         14.000000        19.000000             8000.000000     3.000000
#
#    stats_trueDamageDealtToChampions  stats_perk4Var2  \
# 0                       1642.333333         0.333333
# 1                       1926.000000         0.000000
# 2                        622.977273       164.210227
# 3                        915.481481       404.074074
# 4                       1196.000000         0.000000
#
#    stats_largestCriticalStrike  stats_goldEarned  stats_wardsKilled  \
# 0                     0.000000       9976.000000           5.000000
# 1                     0.000000       7359.000000           0.000000
# 2                    37.181818      10229.272727           5.846591
# 3                    12.370370       7224.074074           2.740741
# 4                     0.000000       9985.000000           0.000000
#
#    stats_item3  ...  stats_totalDamageDealtToChampions  stats_perk2Var2  \
# 0  2728.666667  ...                       15732.666667        16.666667
# 1     0.000000  ...                        9940.000000         0.000000
# 2  2286.079545  ...                       15841.664773         9.017045
# 3  2399.111111  ...                        8625.333333         0.777778
# 4  1413.000000  ...                       11445.000000        50.000000
#
#    stats_perk5Var1  stats_magicDamageDealtToChampions  stats_goldSpent  \
# 0       125.666667                        8290.666667      9008.333333
# 1       334.000000                        6278.000000      6900.000000
# 2       974.664773                        7830.607955      9354.488636
# 3       473.185185                        6114.444444      6418.518519
# 4         6.000000                        1871.000000      9983.000000
#
#    stats_kda   stats_gpm   stats_dpm  num_of_games  player_summonerName
# 0   3.121212  351.050670  555.907321             3                  GOZ
# 1   3.000000  374.186441  505.423729             1                  Luê
# 2   3.205311  398.309467  598.789089           176                  Tcº
# 3   7.665638  279.881384  330.586853            27                  ccº
# 4   1.714286  367.546012  421.288344             1                  sjº
#
# [5 rows x 88 columns]

# %% [markdown]
# ##### Use only summoners with 50+ games from our dataset

# %%
stats_adjusted = stats[stats["num_of_games"] > 50]

# %%
# Visualize Gpm vs Dpm by Summoner
fig = px.scatter(stats_adjusted, x = "stats_gpm", y = "stats_dpm", 
                 color = "player_summonerName", 
                 labels = {"stats_gpm": "Gold/min",
                          "stats_dpm": "Damage/min",
                          "player_summonerName": "Summoners"},
               #  hover_data = {"Champ": players["championId"]},
           template="simple_white", title = "Summoner Gold Per Minute vs Damage Per Minute")

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="7d04e2dc-5c68-45b7-8387-0363d6198bab" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7d04e2dc-5c68-45b7-8387-0363d6198bab")) {
#                     Plotly.newPlot(
#                         '7d04e2dc-5c68-45b7-8387-0363d6198bab',
#                         [{"hovertemplate": "Summoners=             Tc\u00ba<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "             Tc\u00ba", "marker": {"color": "#1F77B4", "symbol": "circle"}, "mode": "markers", "name": "             Tc\u00ba", "showlegend": true, "type": "scattergl", "x": [398.30946710136567], "xaxis": "x", "y": [598.7890891111282], "yaxis": "y"}, {"hovertemplate": "Summoners= Sudzzi<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": " Sudzzi", "marker": {"color": "#FF7F0E", "symbol": "circle"}, "mode": "markers", "name": " Sudzzi", "showlegend": true, "type": "scattergl", "x": [398.52693912830085], "xaxis": "x", "y": [619.196038755558], "yaxis": "y"}, {"hovertemplate": "Summoners=0 Negative Grey<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "0 Negative Grey", "marker": {"color": "#2CA02C", "symbol": "circle"}, "mode": "markers", "name": "0 Negative Grey", "showlegend": true, "type": "scattergl", "x": [370.89080745984154], "xaxis": "x", "y": [597.0984091623583], "yaxis": "y"}, {"hovertemplate": "Summoners=0 n a t<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "0 n a t", "marker": {"color": "#D62728", "symbol": "circle"}, "mode": "markers", "name": "0 n a t", "showlegend": true, "type": "scattergl", "x": [356.9688605037372], "xaxis": "x", "y": [510.73934318954], "yaxis": "y"}, {"hovertemplate": "Summoners=02 13 2001<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "02 13 2001", "marker": {"color": "#9467BD", "symbol": "circle"}, "mode": "markers", "name": "02 13 2001", "showlegend": true, "type": "scattergl", "x": [436.62017284523705], "xaxis": "x", "y": [638.1641828785692], "yaxis": "y"}, {"hovertemplate": "Summoners=057<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "057", "marker": {"color": "#8C564B", "symbol": "circle"}, "mode": "markers", "name": "057", "showlegend": true, "type": "scattergl", "x": [422.50494794319184], "xaxis": "x", "y": [631.6212297249557], "yaxis": "y"}, {"hovertemplate": "Summoners=07 06 00<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "07 06 00", "marker": {"color": "#E377C2", "symbol": "circle"}, "mode": "markers", "name": "07 06 00", "showlegend": true, "type": "scattergl", "x": [403.4912353651044], "xaxis": "x", "y": [458.5147410644368], "yaxis": "y"}, {"hovertemplate": "Summoners=0rangeflower<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "0rangeflower", "marker": {"color": "#7F7F7F", "symbol": "circle"}, "mode": "markers", "name": "0rangeflower", "showlegend": true, "type": "scattergl", "x": [307.31040862854206], "xaxis": "x", "y": [419.6542534650533], "yaxis": "y"}, {"hovertemplate": "Summoners=1 800 Jungle<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "1 800 Jungle", "marker": {"color": "#BCBD22", "symbol": "circle"}, "mode": "markers", "name": "1 800 Jungle", "showlegend": true, "type": "scattergl", "x": [391.7232469124022], "xaxis": "x", "y": [514.3042407247814], "yaxis": "y"}, {"hovertemplate": "Summoners=1 Shady<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "1 Shady", "marker": {"color": "#17BECF", "symbol": "circle"}, "mode": "markers", "name": "1 Shady", "showlegend": true, "type": "scattergl", "x": [319.6697245236133], "xaxis": "x", "y": [395.0634017477254], "yaxis": "y"}, {"hovertemplate": "Summoners=1 doubt<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "1 doubt", "marker": {"color": "#1F77B4", "symbol": "circle"}, "mode": "markers", "name": "1 doubt", "showlegend": true, "type": "scattergl", "x": [266.13622286525595], "xaxis": "x", "y": [273.8076262080047], "yaxis": "y"}, {"hovertemplate": "Summoners=10 lQ PLAYER<br>Gold/min=%{x}<br>Damage/min=%{y}<extra></extra>", "legendgroup": "10 lQ PLAYER", "marker": {"color": "#FF7F0E", "symbol": "circle"}, "mode": "markers", "name": "10 lQ PLAYER", "showlegend": true, "type": "scattergl", "x":  ...

# %%
stats_adjusted["stats_damage_gold_ratio"] = stats_adjusted["stats_dpm"] / stats_adjusted["stats_gpm"]
# Out:
# C:\Users\Stephen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
stats_adjusted
# Out:
#        stats_champLevel  stats_perk4Var1  stats_perkPrimaryStyle  stats_kills  \
# 2             13.272727       777.659091             8091.477273     6.159091
# 133           14.261745       801.973154             8104.026846     4.879195
# 179           13.532609       330.521739             8092.391304     5.217391
# 181           12.745283       400.924528             8100.943396     4.905660
# 213           13.562044      1189.211679             8096.350365     7.875912
# ...                 ...              ...                     ...          ...
# 45608         13.830357       448.866071             8090.178571     4.928571
# 45624         14.279221       413.461039             8082.467532     8.272727
# 45644         12.548387      1000.451613             8077.419355     4.322581
# 45823         12.581818       493.654545             8309.090909     3.545455
# 45826         14.385321       322.724771             8069.724771     7.238532
#
#        stats_trueDamageDealtToChampions  stats_perk4Var2  \
# 2                            622.977273       164.210227
# 133                          594.832215       166.523490
# 179                         1205.391304        11.750000
# 181                         1067.490566        13.509434
# 213                         1749.167883       171.350365
# ...                                 ...              ...
# 45608                        393.392857       358.348214
# 45624                       1095.422078        43.136364
# 45644                        619.596774       433.645161
# 45823                        874.109091       149.290909
# 45826                       2299.678899       115.330275
#
#        stats_largestCriticalStrike  stats_goldEarned  stats_wardsKilled  \
# 2                        37.181818      10229.272727           5.846591
# 133                      25.885906      10792.523490           2.530201
# 179                       6.369565       9675.554348           3.423913
# 181                      55.801887       9394.745283           3.679245
# 213                      21.554745      11506.810219           4.459854
# ...                            ...               ...                ...
# 45608                   244.633929      10805.205357           3.366071
# 45624                   148.500000      11915.240260           3.818182
# 45644                   351.741935       9926.306452           3.064516
# 45823                    41.636364       8997.072727           4.963636
# 45826                    23.944954      11627.853211           2.449541
#
#        stats_item3  ...  stats_perk2Var2  stats_perk5Var1  \
# 2      2286.079545  ...         9.017045       974.664773
# 133    2307.429530  ...         9.838926       852.026846
# 179    2160.532609  ...         5.543478       172.619565
# 181    2472.801887  ...         9.735849       270.132075
# 213    2376.722628  ...         5.795620       483.708029
# ...            ...  ...              ...              ...
# 45608  2146.044643  ...        10.535714       137.214286
# 45624  2780.116883  ...        12.909091       568.155844
# 45644  2835.322581  ...         6.612903        79.548387
# 45823  2660.327273  ...        10.600000       205.327273
# 45826  2323.045872  ...        14.403670       727.394495
#
#        stats_magicDamageDealtToChampions  stats_goldSpent  stats_kda  \
# 2                            7830.607955      9354.488636   3.205311
# 133                         11331.093960      9631.530201   3.885596
# 179                         13201.402174      8968.782609   3.982224
# 181                          6688.009434      8659.896226   3.296317
# 213                          9159.941606     11117.795620   3.268029
# ...                                  ...              ...        ...
# 45608                        8061.205357      9834.392857   3.633990
# 45624                       10642.662338     10742.051948   3.932306
# 45644                        2548.629032      9173.629032   2.926517
# 45823                        6168.909091      8017.000000   8.080758
# 45826                        5441.495413     10939.633028   3.007309
#
#         stats_gpm   stats_dpm  num_of_games  player_summonerName  \
# 2      398.309467  598.789089           176                  Tcº
# 133    398.526939  619.196039           149               Sudzzi
# 179    370.890807  597.098409            92      0 Negative Grey
# 181    356.968861  510.739343           106              0 n a t
# 213    436.620173  638.164183           137           02 13 2001
# ...           ...         ...           ...                  ...
# 45608  405.710928  572.571436           112             õh la la
# 45624  421.602164  736.317521           154                  ćam
# 45644  386.531707  494.257198            62                  ŁTD
# 45823  360.472415  391.814636            55                  我草了
# 45826  434.576640  697.475995           109                  톱 왕
#
#        stats_damage_gold_ratio
# 2                     1.503326
# 133                   1.553712
# 179                   1.609904
# 181                   1.430767
# 213                   1.461600
# ...                        ...
# 45608                 1.411279
# 45624                 1.746475
# 45644                 1.278698
# 45823                 1.086948
# 45826                 1.604955
#
# [1380 rows x 89 columns]

# %%
# Visualize DMG/Gold vs KDA by summoner
fig = px.scatter(stats_adjusted, x = "stats_damage_gold_ratio", y = "stats_kda", 
                 color = "player_summonerName", 
                 labels = {"stats_kda": "Kill Death Average",
                          "stats_damage_gold_ratio": "Damage/Gold",
                          "player_summonerName": "Summoners"},
                 hover_data = {"Vision Score": stats_adjusted["stats_wardsKilled"],
                              "Number of Games": stats_adjusted["num_of_games"]},
           template="simple_white", title = "Summoners KDA vs DMG/Gold")

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="db5d4a34-15ef-4bfb-8b77-c4074725771b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db5d4a34-15ef-4bfb-8b77-c4074725771b")) {
#                     Plotly.newPlot(
#                         'db5d4a34-15ef-4bfb-8b77-c4074725771b',
#                         [{"customdata": [[null, null]], "hovertemplate": "Summoners=             Tc\u00ba<br>Damage/Gold=%{x}<br>Kill Death Average=%{y}<br>Vision Score=%{customdata[0]}<br>Number of Games=%{customdata[1]}<extra></extra>", "legendgroup": "             Tc\u00ba", "marker": {"color": "#1F77B4", "symbol": "circle"}, "mode": "markers", "name": "             Tc\u00ba", "showlegend": true, "type": "scattergl", "x": [1.503326279108356], "xaxis": "x", "y": [3.2053108192312747], "yaxis": "y"}, {"customdata": [[null, null]], "hovertemplate": "Summoners= Sudzzi<br>Damage/Gold=%{x}<br>Kill Death Average=%{y}<br>Vision Score=%{customdata[0]}<br>Number of Games=%{customdata[1]}<extra></extra>", "legendgroup": " Sudzzi", "marker": {"color": "#FF7F0E", "symbol": "circle"}, "mode": "markers", "name": " Sudzzi", "showlegend": true, "type": "scattergl", "x": [1.5537118773198302], "xaxis": "x", "y": [3.8855956496896087], "yaxis": "y"}, {"customdata": [[5.846590909090909, 176.0]], "hovertemplate": "Summoners=0 Negative Grey<br>Damage/Gold=%{x}<br>Kill Death Average=%{y}<br>Vision Score=%{customdata[0]}<br>Number of Games=%{customdata[1]}<extra></extra>", "legendgroup": "0 Negative Grey", "marker": {"color": "#2CA02C", "symbol": "circle"}, "mode": "markers", "name": "0 Negative Grey", "showlegend": true, "type": "scattergl", "x": [1.6099035003098845], "xaxis": "x", "y": [3.9822240259740265], "yaxis": "y"}, {"customdata": [[null, null]], "hovertemplate": "Summoners=0 n a t<br>Damage/Gold=%{x}<br>Kill Death Average=%{y}<br>Vision Score=%{customdata[0]}<br>Number of Games=%{customdata[1]}<extra></extra>", "legendgroup": "0 n a t", "marker": {"color": "#D62728", "symbol": "circle"}, "mode": "markers", "name": "0 n a t", "showlegend": true, "type": "scattergl", "x": [1.430767217254775], "xaxis": "x", "y": [3.2963172833455845], "yaxis": "y"}, {"customdata": [[null, null]], "hovertemplate": "Summoners=02 13 2001<br>Damage/Gold=%{x}<br>Kill Death Average=%{y}<br>Vision Score=%{customdata[0]}<br>Number of Games=%{customdata[1]}<extra></extra>", "legendgroup": "02 13 2001", "marker": {"color": "#9467BD", "symbol": "circle"}, "mode": "markers", "name": "02 13 2001", "showlegend": true, "type": "scattergl", "x": [1.4616003166321196], "xaxis": "x", "y": [3.2680289702187513], "yaxis": "y"}, {"customdata": [[null, null]], "hovertemplate": "Summoners=057<br>Damage/Gold=%{x}<br>Kill Death Average=%{y}<br>Vision Score=%{customdata[0]}<br>Number of Games=%{customdata[1]}<extra></extra>", "legendgroup": "057", "marker": {"color": "#8C564B", "symbol": "circle"}, "mode": "markers", "name": "057", "showlegend": true, "type": "scattergl", "x": [1.49494398302261], "xaxis": "x", "y": [4.809046922862714], "yaxis": "y"}, {"customdata": [[null, null]], "hovertemplate": "Summoners=07 06 00<br>Damage/Gold=%{x}<br>Kill Death Average=%{y}<br>Vision Score=%{customdata[0]}<br>Number of Games=%{customdata[1]}<extra></extra>", "legendgroup": "07 06 00", "marker": {"color": "#E377C2", "symbol": "circle"}, "mode": "markers", "name": "07 06 00", "showlegend": true, "type": "scattergl", "x": [1.1363685276820044], "xaxis": "x", "y": [5.023073476702508], "yaxis": "y"}, {"customdata": [[null, null]], "hovertemplate": "Summoners=0rangeflower<br>Damage/Gold=%{x}<br>Kill Death Average=%{y}<br>Vision Score=%{customdata[0]}<br>Number of Games=%{customdata[1]}<extra></extra>", "legendgroup": "0rangeflower", "marker": {"color": "#7F7F7F", "symbol": "circle"}, "mode": "markers", "name": "0rangeflower", "showlegend": true, "type": "scattergl", "x": [1.3655712324807896], "xaxis": "x", "y": [7.518822553897183], "yaxis": "y"}, {"customdata": [[null, null]], "hovertemplate": "Summoners=1 800 Jungle<br>Damage/Gold=%{x}<br>Kill Death Average=%{y}<br>Vision Score=%{customdata[0]}<br>Number of Games=%{customdata[1]}<extra></extra>", "legendgroup": "1 800 Jungle", "marker": {"color": "#BCBD22", "symbol": "circle"}, "mode": "markers", "name": "1 800 Jungle", "showlegend": true, "type": "scatter ...

# %% [markdown]
# ## Get Dataframe of C9 Accounts

# %%
# C9 accounts found at trackingthepros.com
c9_starting_players = {"Vulcan": ["C9 Vulcan", 'C9 VULCANNN'],
                        "Zven": ["C9 ZVENNN", "C9 Zven"],
                        "Nisqy": ["C9C9C9C9C9", "134679316497"],
                        "Blaber": ["blaberfish2"],
                        "Licorice": ["Licorice"]}

# %%
c9_names = [item for elem in list(c9_starting_players.values()) for item in elem]
print('C9 Players: {}'.format(c9))
# Out:
# C9 Players: ['C9 Vulcan', 'C9 VULCANNN', 'C9 ZVENNN', 'C9 Zven', 'C9C9C9C9C9', '134679316497', 'blaberfish2', 'Licorice']

# %%
c9_indexes = []
for item in c9_names:
    x = stats_adjusted[stats_adjusted["player_summonerName"].str.contains(item) == True].index
    if len(x) > 0:
        c9_indexes.append(x[0])
    else:
        print("The summoner {} was not found.".format(item))
# Out:
# The summoner Licorice was not found.

# %%
c9_names
# Out:
# ['C9 Vulcan',
#  'C9 VULCANNN',
#  'C9 ZVENNN',
#  'C9 Zven',
#  'C9C9C9C9C9',
#  '134679316497',
#  'blaberfish2',
#  'Licorice']

# %%
def fn(row, c9_names):
    if row in c9_names:
        return True
    else:
        return False

# %%
stats_adjusted["c9"] = stats_adjusted["player_summonerName"].apply(lambda row:fn(row, c9_names))
# Out:
# C:\Users\Stephen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
stats_adjusted[stats_adjusted["c9"] == True]
# Out:
#        stats_champLevel  stats_perk4Var1  stats_perkPrimaryStyle  stats_kills  \
# 433           14.171123       846.342246             8128.342246     5.721925
# 5379          12.020270       310.385135             8327.027027     2.195946
# 5381          12.117117       323.171171             8342.342342     2.036036
# 5383          13.320388      1155.242718             8051.456311     5.757282
# 5388          13.464455       930.715640             8060.663507     5.227488
# 5392          13.840909       824.852273             8139.772727     5.363636
# 37162         14.164179       498.895522             8100.000000     7.791045
#
#        stats_trueDamageDealtToChampions  stats_perk4Var2  \
# 433                          638.860963       340.588235
# 5379                         909.695946        69.074324
# 5381                         587.675676        46.180180
# 5383                         400.330097      1121.980583
# 5388                         501.857820       697.734597
# 5392                         477.363636       211.772727
# 37162                       2089.343284        62.940299
#
#        stats_largestCriticalStrike  stats_goldEarned  stats_wardsKilled  \
# 433                      51.358289      11075.737968           2.775401
# 5379                     18.750000       7698.047297           7.885135
# 5381                     42.243243       7656.864865           8.729730
# 5383                    397.116505      11910.844660           5.776699
# 5388                    176.914692      11743.559242           5.142180
# 5392                     19.170455      10734.011364           2.284091
# 37162                    47.029851      11978.477612           6.014925
#
#        stats_item3  ...  stats_perk5Var1  stats_magicDamageDealtToChampions  \
# 433    2468.545455  ...       920.540107                       13083.973262
# 5379   2823.810811  ...       660.054054                        5049.250000
# 5381   2849.639640  ...       741.450450                        5796.684685
# 5383   2130.873786  ...       236.300971                        3455.310680
# 5388   2301.720379  ...       646.341232                        6335.165877
# 5392   2371.943182  ...       883.965909                       14548.545455
# 37162  2831.671642  ...       716.059701                        5802.328358
#
#        stats_goldSpent  stats_kda   stats_gpm   stats_dpm  num_of_games  \
# 433       10132.657754   4.433676  427.023481  668.767165           187
# 5379       6936.304054   4.724295  291.025909  315.904596           148
# 5381       6849.621622   5.754991  294.378242  346.163662           111
# 5383      10721.504854   4.294934  450.169273  653.267988           103
# 5388      10548.194313   4.548852  445.629961  656.751750           211
# 5392       9889.500000   4.657821  419.509167  669.304635            88
# 37162     10868.671642   3.857399  446.258604  675.265741            67
#
#        player_summonerName  stats_damage_gold_ratio    c9
# 433           134679316497                 1.566113  True
# 5379           C9 VULCANNN                 1.085486  True
# 5381             C9 Vulcan                 1.175915  True
# 5383             C9 ZVENNN                 1.451161  True
# 5388               C9 Zven                 1.473760  True
# 5392            C9C9C9C9C9                 1.595447  True
# 37162          blaberfish2                 1.513171  True
#
# [7 rows x 90 columns]

# %%
stats_adjusted.player_summonerName
# Out:
# 2                     Tcº
# 133                Sudzzi
# 179       0 Negative Grey
# 181               0 n a t
# 213            02 13 2001
#                ...
# 45608            õh la la
# 45624                 ćam
# 45644                 ŁTD
# 45823                 我草了
# 45826                 톱 왕
# Name: player_summonerName, Length: 1380, dtype: object

# %%
## Visualize Gpm vs Dpm by Summoner
fig = px.scatter(stats_adjusted, x = "stats_gpm", y = "stats_dpm", 
                 color = 'c9' , 
                 labels = {"stats_gpm": "Gold/min",
                          "stats_dpm": "Damage/min",
                          "player_summonerName": "Summoner"},
                 hover_data = {"player_summonerName": "Summoner"},
           template="simple_white", title = "Summoner Gold Per Minute vs Damage Per Minute")

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="d9071e1d-f314-4a9c-bace-3c09ea1310a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d9071e1d-f314-4a9c-bace-3c09ea1310a9")) {
#                     Plotly.newPlot(
#                         'd9071e1d-f314-4a9c-bace-3c09ea1310a9',
#                         [{"customdata": [["             Tc\u00ba"], [" Sudzzi"], ["0 Negative Grey"], ["0 n a t"], ["02 13 2001"], ["057"], ["07 06 00"], ["0rangeflower"], ["1 800 Jungle"], ["1 Shady"], ["1 doubt"], ["10 lQ PLAYER"], ["100 Copy"], ["100 Kenvi"], ["100 Poome"], ["100 Prismal"], ["100 Tenacity"], ["100 Yeon"], ["100100"], ["121499"], ["123asdqwe321"], ["15 jojopyun"], ["16cm"], ["1936 1948"], ["1996 03 29"], ["1dayfly"], ["1stPlaceSnowGurb"], ["20200120"], ["2035"], ["2HERO2"], ["3 PC SPICY COMBO"], ["37\u00ba2"], ["3uphoria"], ["4 Stars"], ["41205"], ["434343"], ["4inch is average"], ["50 Fury W"], ["5fire"], ["5ft latina gf"], ["5tunt"], ["69 at baron uwu"], ["8 Pack Olaf"], ["961216"], ["9Lives"], ["9k jg"], ["A 5"], ["A MESS"], ["ADCADC123"], ["AND 1 AIDAN"], ["ASTROBOY99"], ["AZ Yeongin"], ["Aaron9"], ["Ablazeolive"], ["Abou222"], ["About 39 Goats"], ["About Me"], ["Acce1"], ["Acilion"], ["Acilion2"], ["Adrian Seira"], ["Aesthetic9"], ["Afreeca Kiin"], ["AgileSeahawk"], ["Ahsayuni"], ["Aizo"], ["AkDuke"], ["Albus NoX"], ["Aldnoah"], ["Alex Blais"], ["AlienLion"], ["Alistar"], ["All Pressure"], ["Allorim"], ["Aloned"], ["AltecJohnny"], ["Amayzing"], ["AnAnorexicPanda"], ["AnDa"], ["Andresu7NA"], ["AnduhRoux"], ["Andybendy"], ["Anivvia"], ["Anlvia Guy"], ["Annie Bot"], ["Antic\u00edpation"], ["Apathing"], ["ApeXsnipe"], ["Aphelios x Sett"], ["AquaBlue"], ["Arcsecond"], ["ArgentumSky"], ["Armored Mawdad"], ["Array adc"], ["Artis"], ["Asgeir21"], ["Aspe\u00e7t"], ["Assurance"], ["Asyc"], ["Auntie Ana"], ["Autolykus"], ["Avano"], ["Awake\u0144"], ["Ayzz"], ["Azut\u00f8"], ["BB Shmurda"], ["BEST POUTINE QC"], ["BG1"], ["BOBtimer"], ["BTang"], ["BUKZACH DISCIPLE"], ["BUZZLIGHTYEAR99"], ["Babe Cat"], ["Baby sad"], ["Bad Rat xD"], ["Baeyron"], ["BarbaricDictator"], ["BatBoyMelee"], ["Bathrobe King"], ["Batmun"], ["BeBePro"], ["BearlyArmed"], ["Benjil0l"], ["BeowuIf"], ["Berik"], ["Big Opai"], ["BigMagicDonger"], ["Biofrost "], ["BladeCube"], ["BladeGO"], ["BlindEyedWarrior"], ["Blitz"], ["Blower"], ["BlueRainn"], ["Bmfx"], ["Bobbytea"], ["BootySIapper"], ["BoxBox"], ["Boy Wonder"], ["BrandonASF"], ["Breezyyy"], ["Brown Man Darius"], ["Bruder"], ["BukZacH"], ["Burai"], ["Busio"], ["Busio3"], ["BusioC"], ["Bu\u00f5n Gi\u00f5rn\u00f5"], ["Bxxxx9x Txxx Gxx"], ["Bykrhn"], ["B\u00d8DY"], ["B\u00e1nh M\u00ec xD"], ["B\u00edg T"], ["C405"], ["C9 Diamond"], ["C9 Manny"], ["CAPTAIN OF CRUSH"], ["CASS7DY"], ["CDamon"], ["CHlME"], ["CIyde"], ["CLG Ravey"], ["CP Freeze"], ["CanOpener89"], ["CantCarry"], ["Captain Stevie B"], ["Caristinn"], ["Carthage"], ["Cat is bot"], ["CatOnThyRoof"], ["Catch a Body"], ["Cavele"], ["Cemonic"], ["Certified Noob"], ["Chad Jungle"], ["Chaddington"], ["Chaloc"], ["ChaosRain"], ["Chas3"], ["Chase"], ["CheIsea Smile"], ["Chicken LittIe"], ["ChickenNugget"], ["Chillin W MyHarp"], ["Chimp"], ["Choisix"], ["Chovy Dopa Faker"], ["ChuChuZ"], ["Cidez"], ["Circus"], ["Citric"], ["CjSphinx"], ["Clear Upgrade"], ["CllT2SIw83Q"], ["ClownServer1"], ["Coco9"], ["Cody Pog"], ["Competition9"], ["Concuerdo"], ["Consume Adapt"], ["Con\ufb01dence"], ["Cookie Sonic"], ["CookiesforSanta"], ["Cop\u00fd"], ["Cosmic Fall"], ["Cozy Shroud"], ["CptShrimps"], ["Crayon  Shin"], ["Crucile 1"], ["Cult"], ["Cupic"], ["Cute Asian Loli"], ["Cxa"], ["Cynestro"], ["Cyrus D"], ["D0G2"], ["DARK WlNGS"], ["DCSNT"], ["DEEBO SAMUEL "], ["DIAMOND 2 JG"], ["DIG Asta"], ["DISCO YASUO"], ["DISCORD TARZANED"], ["DJ Y4ssin"], ["DVASDGKSAJHGHSJK"], ["DaPointGuard"], ["Dahyun x Twice"], ["Daikong"], ["Dal Byul"], ["Damonte"], ["DanasaurLoL"], ["Daption"], ["DarbBarf"], ["Dea\u00f1"], ["DeductedCarlos"], ["Demigod"], ["Descraton"], ["Detention"], ["Devil deGrey5"], ["De\u00dftiny"], ["Dhokla"], ["Diamond Emperor"], ["Dictraction"], ["Dinka"], ["Dirt Farmer"], ["Disconnector"], ["Djalal"], ["Doaenel"], ["Dobby P"], ["Don Rom"], ["Doo liss"], ["Doopl\u00edss"], ["Double Deans"], ["Doublelift"], ["Doubtfull"], ["DoughnutDrew"], ["Doxa"], ["Dragarri ...

# %%
###
