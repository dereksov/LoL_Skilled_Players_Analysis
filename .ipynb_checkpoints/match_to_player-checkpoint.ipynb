# %% [markdown]
# # import, csv, json

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf   
## if error: python3.6 -m pip install scipy==1.2 --upgrade
import json 
import pprint

# %%
df = pd.read_csv('data/clean.csv',low_memory=False)
print(df.shape)
# Out:
# (29473, 1186)

# %%
# Opening JSON file 

## http://ddragon.leagueoflegends.com/cdn/10.14.1/data/en_US/champion.json
## change the 10.14 to whatever the current patch is, for all champion data

with open('data/championids.json',  encoding='utf-8') as f:
    champion_data = json.load(f)
f.close()

# %%
print(champion_data.keys())
# Out:
# dict_keys(['type', 'format', 'version', 'data'])

# %%
pprint.pprint(champion_data['data'])
# Out:
# {'Aatrox': {'blurb': 'Once honored defenders of Shurima against the Void, '
#                      'Aatrox and his brethren would eventually become an even '
#                      'greater threat to Runeterra, and were defeated only by '
#                      'cunning mortal sorcery. But after centuries of '
#                      'imprisonment, Aatrox was the first to find...',
#             'id': 'Aatrox',
#             'image': {'full': 'Aatrox.png',
#                       'group': 'champion',
#                       'h': 48,
#                       'sprite': 'champion0.png',
#                       'w': 48,
#                       'x': 0,
#                       'y': 0},
#             'info': {'attack': 8, 'defense': 4, 'difficulty': 4, 'magic': 3},
#             'key': '266',
#             'name': 'Aatrox',
#             'partype': 'Blood Well',
#             'stats': {'armor': 38,
#                       'armorperlevel': 3.25,
#                       'attackdamage': 60,
#                       'attackdamageperlevel': 5,
#                       'attackrange': 175,
#                       'attackspeed': 0.651,
#                       'attackspeedperlevel': 2.5,
#                       'crit': 0,
#                       'critperlevel': 0,
#                       'hp': 580,
#                       'hpperlevel': 90,
#                       'hpregen': 3,
#                       'hpregenperlevel': 1,
#                       'movespeed': 345,
#                       'mp': 0,
#                       'mpperlevel': 0,
#                       'mpregen': 0,
#                       'mpregenperlevel': 0,
#                       'spellblock': 32.1,
#                       'spellblockperlevel': 1.25},
#             'tags': ['Fighter', 'Tank'],
#             'title': 'the Darkin Blade',
#             'version': '10.14.1'},
#  'Ahri': {'blurb': 'Innately connected to the latent power of Runeterra, Ahri '
#                    'is a vastaya who can reshape magic into orbs of raw '
#                    'energy. She revels in toying with her prey by manipulating '
#                    'their emotions before devouring their life essence. '
#                    'Despite her predatory nature...',
#           'id': 'Ahri',
#           'image': {'full': 'Ahri.png',
#                     'group': 'champion',
#                     'h': 48,
#                     'sprite': 'champion0.png',
#                     'w': 48,
#                     'x': 48,
#                     'y': 0},
#           'info': {'attack': 3, 'defense': 4, 'difficulty': 5, 'magic': 8},
#           'key': '103',
#           'name': 'Ahri',
#           'partype': 'Mana',
#           'stats': {'armor': 20.88,
#                     'armorperlevel': 3.5,
#                     'attackdamage': 53.04,
#                     'attackdamageperlevel': 3,
#                     'attackrange': 550,
#                     'attackspeed': 0.668,
#                     'attackspeedperlevel': 2,
#                     'crit': 0,
#                     'critperlevel': 0,
#                     'hp': 526,
#                     'hpperlevel': 92,
#                     'hpregen': 6.5,
#                     'hpregenperlevel': 0.6,
#                     'movespeed': 330,
#                     'mp': 418,
#                     'mpperlevel': 25,
#                     'mpregen': 8,
#                     'mpregenperlevel': 0.8,
#                     'spellblock': 30,
#                     'spellblockperlevel': 0.5},
#           'tags': ['Mage', 'Assassin'],
#           'title': 'the Nine-Tailed Fox',
#           'version': '10.14.1'},
#  'Akali': {'blurb': 'Abandoning the Kinkou Order and her title of the Fist of '
#                     'Shadow, Akali now strikes alone, ready to be the deadly '
#                     'weapon her people need. Though she holds onto all she '
#                     'learned from her master Shen, she has pledged to defend '
#                     'Ionia from its enemies, one...',
#            'id': 'Akali',
#            'image': {'full': 'Akali.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion0.png',
#                      'w': 48,
#                      'x': 96,
#                      'y': 0},
#            'info': {'attack': 5, 'defense': 3, 'difficulty': 7, 'magic': 8},
#            'key': '84',
#            'name': 'Akali',
#            'partype': 'Energy',
#            'stats': {'armor': 23,
#                      'armorperlevel': 3.5,
#                      'attackdamage': 62.4,
#                      'attackdamageperlevel': 3.3,
#                      'attackrange': 125,
#                      'attackspeed': 0.625,
#                      'attackspeedperlevel': 3.2,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 575,
#                      'hpperlevel': 95,
#                      'hpregen': 8,
#                      'hpregenperlevel': 0.5,
#                      'movespeed': 345,
#                      'mp': 200,
#                      'mpperlevel': 0,
#                      'mpregen': 50,
#                      'mpregenperlevel': 0,
#                      'spellblock': 37,
#                      'spellblockperlevel': 1.25},
#            'tags': ['Assassin'],
#            'title': 'the Rogue Assassin',
#            'version': '10.14.1'},
#  'Alistar': {'blurb': 'Always a mighty warrior with a fearsome reputation, '
#                       'Alistar seeks revenge for the death of his clan at the '
#                       'hands of the Noxian empire. Though he was enslaved and '
#                       'forced into the life of a gladiator, his unbreakable '
#                       'will was what kept him from truly...',
#              'id': 'Alistar',
#              'image': {'full': 'Alistar.png',
#                        'group': 'champion',
#                        'h': 48,
#                        'sprite': 'champion0.png',
#                        'w': 48,
#                        'x': 144,
#                        'y': 0},
#              'info': {'attack': 6, 'defense': 9, 'difficulty': 7, 'magic': 5},
#              'key': '12',
#              'name': 'Alistar',
#              'partype': 'Mana',
#              'stats': {'armor': 44,
#                        'armorperlevel': 3.5,
#                        'attackdamage': 62,
#                        'attackdamageperlevel': 3.75,
#                        'attackrange': 125,
#                        'attackspeed': 0.625,
#                        'attackspeedperlevel': 2.125,
#                        'crit': 0,
#                        'critperlevel': 0,
#                        'hp': 600,
#                        'hpperlevel': 106,
#                        'hpregen': 8.5,
#                        'hpregenperlevel': 0.85,
#                        'movespeed': 330,
#                        'mp': 350,
#                        'mpperlevel': 40,
#                        'mpregen': 8.5,
#                        'mpregenperlevel': 0.8,
#                        'spellblock': 32.1,
#                        'spellblockperlevel': 1.25},
#              'tags': ['Tank', 'Support'],
#              'title': 'the Minotaur',
#              'version': '10.14.1'},
#  'Amumu': {'blurb': 'Legend claims that Amumu is a lonely and melancholy soul '
#                     'from ancient Shurima, roaming the world in search of a '
#                     'friend. Doomed by an ancient curse to remain alone '
#                     'forever, his touch is death, his affection ruin. Those '
#                     'who claim to have seen him describe...',
#            'id': 'Amumu',
#            'image': {'full': 'Amumu.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion0.png',
#                      'w': 48,
#                      'x': 192,
#                      'y': 0},
#            'info': {'attack': 2, 'defense': 6, 'difficulty': 3, 'magic': 8},
#            'key': '32',
#            'name': 'Amumu',
#            'partype': 'Mana',
#            'stats': {'armor': 33,
#                      'armorperlevel': 3.8,
#                      'attackdamage': 53.38,
#                      'attackdamageperlevel': 3.8,
#                      'attackrange': 125,
#                      'attackspeed': 0.736,
#                      'attackspeedperlevel': 2.18,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 613.12,
#                      'hpperlevel': 84,
#                      'hpregen': 9,
#                      'hpregenperlevel': 0.85,
#                      'movespeed': 335,
#                      'mp': 287.2,
#                      'mpperlevel': 40,
#                      'mpregen': 7.382,
#                      'mpregenperlevel': 0.525,
#                      'spellblock': 32.1,
#                      'spellblockperlevel': 1.25},
#            'tags': ['Tank', 'Mage'],
#            'title': 'the Sad Mummy',
#            'version': '10.14.1'},
#  'Anivia': {'blurb': 'Anivia is a benevolent winged spirit who endures endless '
#                      'cycles of life, death, and rebirth to protect the '
#                      'Freljord. A demigod born of unforgiving ice and bitter '
#                      'winds, she wields those elemental powers to thwart any '
#                      'who dare disturb her homeland...',
#             'id': 'Anivia',
#             'image': {'full': 'Anivia.png',
#                       'group': 'champion',
#                       'h': 48,
#                       'sprite': 'champion0.png',
#                       'w': 48,
#                       'x': 240,
#                       'y': 0},
#             'info': {'attack': 1, 'defense': 4, 'difficulty': 10, 'magic': 10},
#             'key': '34',
#             'name': 'Anivia',
#             'partype': 'Mana',
#             'stats': {'armor': 21.22,
#                       'armorperlevel': 4,
#                       'attackdamage': 51.376,
#                       'attackdamageperlevel': 3.2,
#                       'attackrange': 600,
#                       'attackspeed': 0.625,
#                       'attackspeedperlevel': 1.68,
#                       'crit': 0,
#                       'critperlevel': 0,
#                       'hp': 480,
#                       'hpperlevel': 82,
#                       'hpregen': 5.5,
#                       'hpregenperlevel': 0.55,
#                       'movespeed': 325,
#                       'mp': 495,
#                       'mpperlevel': 25,
#                       'mpregen': 8,
#                       'mpregenperlevel': 0.8,
#                       'spellblock': 30,
#                       'spellblockperlevel': 0.5},
#             'tags': ['Mage', 'Support'],
#             'title': 'the Cryophoenix',
#             'version': '10.14.1'},
#  'Annie': {'blurb': 'Dangerous, yet disarmingly precocious, Annie is a child '
#                     'mage with immense pyromantic power. Even in the shadows '
#                     'of the mountains north of Noxus, she is a magical '
#                     'outlier. Her natural affinity for fire manifested early '
#                     'in life through unpredictable...',
#            'id': 'Annie',
#            'image': {'full': 'Annie.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion0.png',
#                      'w': 48,
#                      'x': 288,
#                      'y': 0},
#            'info': {'attack': 2, 'defense': 3, 'difficulty': 6, 'magic': 10},
#            'key': '1',
#            'name': 'Annie',
#            'partype': 'Mana',
#            'stats': {'armor': 19.22,
#                      'armorperlevel': 4,
#                      'attackdamage': 50.41,
#                      'attackdamageperlevel': 2.625,
#                      'attackrange': 625,
#                      'attackspeed': 0.579,
#                      'attackspeedperlevel': 1.36,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 524,
#                      'hpperlevel': 88,
#                      'hpregen': 5.5,
#                      'hpregenperlevel': 0.55,
#                      'movespeed': 335,
#                      'mp': 418,
#                      'mpperlevel': 25,
#                      'mpregen': 8,
#                      'mpregenperlevel': 0.8,
#                      'spellblock': 30,
#                      'spellblockperlevel': 0.5},
#            'tags': ['Mage'],
#            'title': 'the Dark Child',
#            'version': '10.14.1'},
#  'Aphelios': {'blurb': "Emerging from moonlight's shadow with weapons drawn, "
#                        'Aphelios kills the enemies of his faith in brooding '
#                        'silence—speaking only through the certainty of his '
#                        'aim, and the firing of each gun. Though fueled by a '
#                        'poison that renders him mute, he is guided by...',
#               'id': 'Aphelios',
#               'image': {'full': 'Aphelios.png',
#                         'group': 'champion',
#                         'h': 48,
#                         'sprite': 'champion0.png',
#                         'w': 48,
#                         'x': 336,
#                         'y': 0},
#               'info': {'attack': 6, 'defense': 2, 'difficulty': 10, 'magic': 1},
#               'key': '523',
#               'name': 'Aphelios',
#               'partype': 'Mana',
#               'stats': {'armor': 28,
#                         'armorperlevel': 3,
#                         'attackdamage': 57,
#                         'attackdamageperlevel': 2,
#                         'attackrange': 550,
#                         'attackspeed': 0.64,
#                         'attackspeedperlevel': 2.1,
#                         'crit': 0,
#                         'critperlevel': 0,
#                         'hp': 530,
#                         'hpperlevel': 88,
#                         'hpregen': 3.25,
#                         'hpregenperlevel': 0.55,
#                         'movespeed': 325,
#                         'mp': 348,
#                         'mpperlevel': 42,
#                         'mpregen': 6.5,
#                         'mpregenperlevel': 0.4,
#                         'spellblock': 26,
#                         'spellblockperlevel': 0.5},
#               'tags': ['Marksman'],
#               'title': 'the Weapon of the Faithful',
#               'version': '10.14.1'},
#  'Ashe': {'blurb': 'Iceborn warmother of the Avarosan tribe, Ashe commands the '
#                    'most populous horde in the north. Stoic, intelligent, and '
#                    'idealistic, yet uncomfortable with her role as leader, she '
#                    'taps into the ancestral magics of her lineage to wield a '
#                    'bow of True Ice...',
#           'id': 'Ashe',
#           'image': {'full': 'Ashe.png',
#                     'group': 'champion',
#                     'h': 48,
#                     'sprite': 'champion0.png',
#                     'w': 48,
#                     'x': 384,
#                     'y': 0},
#           'info': {'attack': 7, 'defense': 3, 'difficulty': 4, 'magic': 2},
#           'key': '22',
#           'name': 'Ashe',
#           'partype': 'Mana',
#           'stats': {'armor': 26,
#                     'armorperlevel': 3.4,
#                     'attackdamage': 61,
#                     'attackdamageperlevel': 2.96,
#                     'attackrange': 600,
#                     'attackspeed': 0.658,
#                     'attackspeedperlevel': 3.33,
#                     'crit': 0,
#                     'critperlevel': 0,
#                     'hp': 570,
#                     'hpperlevel': 87,
#                     'hpregen': 3.5,
#                     'hpregenperlevel': 0.55,
#                     'movespeed': 325,
#                     'mp': 280,
#                     'mpperlevel': 32,
#                     'mpregen': 6.972,
#                     'mpregenperlevel': 0.4,
#                     'spellblock': 30,
#                     'spellblockperlevel': 0.5},
#           'tags': ['Marksman', 'Support'],
#           'title': 'the Frost Archer',
#           'version': '10.14.1'},
#  'AurelionSol': {'blurb': 'Aurelion Sol once graced the vast emptiness of the '
#                           'cosmos with celestial wonders of his own devising. '
#                           'Now, he is forced to wield his awesome power at the '
#                           'behest of a space-faring empire that tricked him '
#                           'into servitude. Desiring a return to his...',
#                  'id': 'AurelionSol',
#                  'image': {'full': 'AurelionSol.png',
#                            'group': 'champion',
#                            'h': 48,
#                            'sprite': 'champion0.png',
#                            'w': 48,
#                            'x': 432,
#                            'y': 0},
#                  'info': {'attack': 2,
#                           'defense': 3,
#                           'difficulty': 7,
#                           'magic': 8},
#                  'key': '136',
#                  'name': 'Aurelion Sol',
#                  'partype': 'Mana',
#                  'stats': {'armor': 19,
#                            'armorperlevel': 3.6,
#                            'attackdamage': 57,
#                            'attackdamageperlevel': 3.2,
#                            'attackrange': 550,
#                            'attackspeed': 0.625,
#                            'attackspeedperlevel': 1.36,
#                            'crit': 0,
#                            'critperlevel': 0,
#                            'hp': 575,
#                            'hpperlevel': 92,
#                            'hpregen': 7,
#                            'hpregenperlevel': 0.6,
#                            'movespeed': 325,
#                            'mp': 350,
#                            'mpperlevel': 50,
#                            'mpregen': 6,
#                            'mpregenperlevel': 0.8,
#                            'spellblock': 30,
#                            'spellblockperlevel': 0.5},
#                  'tags': ['Mage'],
#                  'title': 'The Star Forger',
#                  'version': '10.14.1'},
#  'Azir': {'blurb': 'Azir was a mortal emperor of Shurima in a far distant age, '
#                    'a proud man who stood at the cusp of immortality. His '
#                    'hubris saw him betrayed and murdered at the moment of his '
#                    'greatest triumph, but now, millennia later, he has been '
#                    'reborn as an Ascended...',
#           'id': 'Azir',
#           'image': {'full': 'Azir.png',
#                     'group': 'champion',
#                     'h': 48,
#                     'sprite': 'champion0.png',
#                     'w': 48,
#                     'x': 0,
#                     'y': 48},
#           'info': {'attack': 6, 'defense': 3, 'difficulty': 9, 'magic': 8},
#           'key': '268',
#           'name': 'Azir',
#           'partype': 'Mana',
#           'stats': {'armor': 19.04,
#                     'armorperlevel': 3,
#                     'attackdamage': 52,
#                     'attackdamageperlevel': 2.8,
#                     'attackrange': 525,
#                     'attackspeed': 0.625,
#                     'attackspeedperlevel': 3,
#                     'crit': 0,
#                     'critperlevel': 0,
#                     'hp': 552,
#                     'hpperlevel': 92,
#                     'hpregen': 7,
#                     'hpregenperlevel': 0.75,
#                     'movespeed': 335,
#                     'mp': 480,
#                     'mpperlevel': 21,
#                     'mpregen': 8,
#                     'mpregenperlevel': 0.8,
#                     'spellblock': 30,
#                     'spellblockperlevel': 0.5},
#           'tags': ['Mage', 'Marksman'],
#           'title': 'the Emperor of the Sands',
#           'version': '10.14.1'},
#  'Bard': {'blurb': 'A traveler from beyond the stars, Bard is an agent of '
#                    'serendipity who fights to maintain a balance where life '
#                    'can endure the indifference of chaos. Many Runeterrans '
#                    'sing songs that ponder his extraordinary nature, yet they '
#                    'all agree that the cosmic...',
#           'id': 'Bard',
#           'image': {'full': 'Bard.png',
#                     'group': 'champion',
#                     'h': 48,
#                     'sprite': 'champion0.png',
#                     'w': 48,
#                     'x': 48,
#                     'y': 48},
#           'info': {'attack': 4, 'defense': 4, 'difficulty': 9, 'magic': 5},
#           'key': '432',
#           'name': 'Bard',
#           'partype': 'Mana',
#           'stats': {'armor': 34,
#                     'armorperlevel': 4,
#                     'attackdamage': 52,
#                     'attackdamageperlevel': 3,
#                     'attackrange': 500,
#                     'attackspeed': 0.625,
#                     'attackspeedperlevel': 2,
#                     'crit': 0,
#                     'critperlevel': 0,
#                     'hp': 575,
#                     'hpperlevel': 89,
#                     'hpregen': 5.5,
#                     'hpregenperlevel': 0.55,
#                     'movespeed': 330,
#                     'mp': 350,
#                     'mpperlevel': 50,
#                     'mpregen': 6,
#                     'mpregenperlevel': 0.45,
#                     'spellblock': 30,
#                     'spellblockperlevel': 0.5},
#           'tags': ['Support', 'Mage'],
#           'title': 'the Wandering Caretaker',
#           'version': '10.14.1'},
#  'Blitzcrank': {'blurb': 'Blitzcrank is an enormous, near-indestructible '
#                          'automaton from Zaun, originally built to dispose of '
#                          'hazardous waste. However, he found this primary '
#                          'purpose too restricting, and modified his own form '
#                          'to better serve the fragile people of the Sump...',
#                 'id': 'Blitzcrank',
#                 'image': {'full': 'Blitzcrank.png',
#                           'group': 'champion',
#                           'h': 48,
#                           'sprite': 'champion0.png',
#                           'w': 48,
#                           'x': 96,
#                           'y': 48},
#                 'info': {'attack': 4,
#                          'defense': 8,
#                          'difficulty': 4,
#                          'magic': 5},
#                 'key': '53',
#                 'name': 'Blitzcrank',
#                 'partype': 'Mana',
#                 'stats': {'armor': 37,
#                           'armorperlevel': 3.5,
#                           'attackdamage': 61.54,
#                           'attackdamageperlevel': 3.5,
#                           'attackrange': 125,
#                           'attackspeed': 0.625,
#                           'attackspeedperlevel': 1.13,
#                           'crit': 0,
#                           'critperlevel': 0,
#                           'hp': 582.6,
#                           'hpperlevel': 95,
#                           'hpregen': 8.5,
#                           'hpregenperlevel': 0.75,
#                           'movespeed': 325,
#                           'mp': 267.2,
#                           'mpperlevel': 40,
#                           'mpregen': 8.5,
#                           'mpregenperlevel': 0.8,
#                           'spellblock': 32.1,
#                           'spellblockperlevel': 1.25},
#                 'tags': ['Tank', 'Fighter'],
#                 'title': 'the Great Steam Golem',
#                 'version': '10.14.1'},
#  'Brand': {'blurb': 'Once a tribesman of the icy Freljord named Kegan Rodhe, '
#                     'the creature known as Brand is a lesson in the temptation '
#                     'of greater power. Seeking one of the legendary World '
#                     'Runes, Kegan betrayed his companions and seized it for '
#                     'himself—and, in an instant, the...',
#            'id': 'Brand',
#            'image': {'full': 'Brand.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion0.png',
#                      'w': 48,
#                      'x': 144,
#                      'y': 48},
#            'info': {'attack': 2, 'defense': 2, 'difficulty': 4, 'magic': 9},
#            'key': '63',
#            'name': 'Brand',
#            'partype': 'Mana',
#            'stats': {'armor': 21.88,
#                      'armorperlevel': 3.5,
#                      'attackdamage': 57.04,
#                      'attackdamageperlevel': 3,
#                      'attackrange': 550,
#                      'attackspeed': 0.625,
#                      'attackspeedperlevel': 1.36,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 519.68,
#                      'hpperlevel': 88,
#                      'hpregen': 5.5,
#                      'hpregenperlevel': 0.55,
#                      'movespeed': 340,
#                      'mp': 469,
#                      'mpperlevel': 21,
#                      'mpregen': 10.665,
#                      'mpregenperlevel': 0.6,
#                      'spellblock': 30,
#                      'spellblockperlevel': 0.5},
#            'tags': ['Mage'],
#            'title': 'the Burning Vengeance',
#            'version': '10.14.1'},
#  'Braum': {'blurb': 'Blessed with massive biceps and an even bigger heart, '
#                     'Braum is a beloved hero of the Freljord. Every mead hall '
#                     'north of Frostheld toasts his legendary strength, said to '
#                     'have felled a forest of oaks in a single night, and '
#                     'punched an entire mountain into...',
#            'id': 'Braum',
#            'image': {'full': 'Braum.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion0.png',
#                      'w': 48,
#                      'x': 192,
#                      'y': 48},
#            'info': {'attack': 3, 'defense': 9, 'difficulty': 3, 'magic': 4},
#            'key': '201',
#            'name': 'Braum',
#            'partype': 'Mana',
#            'stats': {'armor': 47,
#                      'armorperlevel': 4,
#                      'attackdamage': 55.376,
#                      'attackdamageperlevel': 3.2,
#                      'attackrange': 125,
#                      'attackspeed': 0.644,
#                      'attackspeedperlevel': 3.5,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 540,
#                      'hpperlevel': 98,
#                      'hpregen': 8.5,
#                      'hpregenperlevel': 1,
#                      'movespeed': 335,
#                      'mp': 310.6,
#                      'mpperlevel': 45,
#                      'mpregen': 6,
#                      'mpregenperlevel': 0.8,
#                      'spellblock': 32.1,
#                      'spellblockperlevel': 1.25},
#            'tags': ['Support', 'Tank'],
#            'title': 'the Heart of the Freljord',
#            'version': '10.14.1'},
#  'Caitlyn': {'blurb': 'Renowned as its finest peacekeeper, Caitlyn is also '
#                       "Piltover's best shot at ridding the city of its elusive "
#                       'criminal elements. She is often paired with Vi, acting '
#                       "as a cool counterpoint to her partner's more impetuous "
#                       'nature. Even though she carries a...',
#              'id': 'Caitlyn',
#              'image': {'full': 'Caitlyn.png',
#                        'group': 'champion',
#                        'h': 48,
#                        'sprite': 'champion0.png',
#                        'w': 48,
#                        'x': 240,
#                        'y': 48},
#              'info': {'attack': 8, 'defense': 2, 'difficulty': 6, 'magic': 2},
#              'key': '51',
#              'name': 'Caitlyn',
#              'partype': 'Mana',
#              'stats': {'armor': 28,
#                        'armorperlevel': 3.5,
#                        'attackdamage': 62,
#                        'attackdamageperlevel': 2.88,
#                        'attackrange': 650,
#                        'attackspeed': 0.681,
#                        'attackspeedperlevel': 4,
#                        'crit': 0,
#                        'critperlevel': 0,
#                        'hp': 510,
#                        'hpperlevel': 93,
#                        'hpregen': 3.5,
#                        'hpregenperlevel': 0.55,
#                        'movespeed': 325,
#                        'mp': 313.7,
#                        'mpperlevel': 35,
#                        'mpregen': 7.4,
#                        'mpregenperlevel': 0.55,
#                        'spellblock': 30,
#                        'spellblockperlevel': 0.5},
#              'tags': ['Marksman'],
#              'title': 'the Sheriff of Piltover',
#              'version': '10.14.1'},
#  'Camille': {'blurb': 'Weaponized to operate outside the boundaries of the '
#                       'law, Camille is the Principal Intelligencer of Clan '
#                       'Ferros—an elegant and elite agent who ensures the '
#                       'Piltover machine and its Zaunite underbelly runs '
#                       'smoothly. Adaptable and precise, she views sloppy...',
#              'id': 'Camille',
#              'image': {'full': 'Camille.png',
#                        'group': 'champion',
#                        'h': 48,
#                        'sprite': 'champion0.png',
#                        'w': 48,
#                        'x': 288,
#                        'y': 48},
#              'info': {'attack': 8, 'defense': 6, 'difficulty': 4, 'magic': 3},
#              'key': '164',
#              'name': 'Camille',
#              'partype': 'Mana',
#              'stats': {'armor': 35,
#                        'armorperlevel': 3.8,
#                        'attackdamage': 68,
#                        'attackdamageperlevel': 3.5,
#                        'attackrange': 125,
#                        'attackspeed': 0.644,
#                        'attackspeedperlevel': 2.5,
#                        'crit': 0,
#                        'critperlevel': 0,
#                        'hp': 575.6,
#                        'hpperlevel': 85,
#                        'hpregen': 8.5,
#                        'hpregenperlevel': 0.8,
#                        'movespeed': 340,
#                        'mp': 338.8,
#                        'mpperlevel': 32,
#                        'mpregen': 8.15,
#                        'mpregenperlevel': 0.75,
#                        'spellblock': 32.1,
#                        'spellblockperlevel': 1.25},
#              'tags': ['Fighter', 'Tank'],
#              'title': 'the Steel Shadow',
#              'version': '10.14.1'},
#  'Cassiopeia': {'blurb': 'Cassiopeia is a deadly creature bent on manipulating '
#                          'others to her sinister will. Youngest and most '
#                          'beautiful daughter of the noble Du Couteau family of '
#                          'Noxus, she ventured deep into the crypts beneath '
#                          'Shurima in search of ancient power. There, she '
#                          'was...',
#                 'id': 'Cassiopeia',
#                 'image': {'full': 'Cassiopeia.png',
#                           'group': 'champion',
#                           'h': 48,
#                           'sprite': 'champion0.png',
#                           'w': 48,
#                           'x': 336,
#                           'y': 48},
#                 'info': {'attack': 2,
#                          'defense': 3,
#                          'difficulty': 10,
#                          'magic': 9},
#                 'key': '69',
#                 'name': 'Cassiopeia',
#                 'partype': 'Mana',
#                 'stats': {'armor': 18,
#                           'armorperlevel': 3.5,
#                           'attackdamage': 53,
#                           'attackdamageperlevel': 3,
#                           'attackrange': 550,
#                           'attackspeed': 0.647,
#                           'attackspeedperlevel': 1.5,
#                           'crit': 0,
#                           'critperlevel': 0,
#                           'hp': 560,
#                           'hpperlevel': 90,
#                           'hpregen': 5.5,
#                           'hpregenperlevel': 0.5,
#                           'movespeed': 328,
#                           'mp': 350,
#                           'mpperlevel': 40,
#                           'mpregen': 8,
#                           'mpregenperlevel': 0.8,
#                           'spellblock': 32,
#                           'spellblockperlevel': 0.5},
#                 'tags': ['Mage'],
#                 'title': "the Serpent's Embrace",
#                 'version': '10.14.1'},
#  'Chogath': {'blurb': "From the moment Cho'Gath first emerged into the harsh "
#                       "light of Runeterra's sun, the beast was driven by the "
#                       'most pure and insatiable hunger. A perfect expression '
#                       "of the Void's desire to consume all life, Cho'Gath's "
#                       'complex biology quickly converts...',
#              'id': 'Chogath',
#              'image': {'full': 'Chogath.png',
#                        'group': 'champion',
#                        'h': 48,
#                        'sprite': 'champion0.png',
#                        'w': 48,
#                        'x': 384,
#                        'y': 48},
#              'info': {'attack': 3, 'defense': 7, 'difficulty': 5, 'magic': 7},
#              'key': '31',
#              'name': "Cho'Gath",
#              'partype': 'Mana',
#              'stats': {'armor': 38,
#                        'armorperlevel': 3.5,
#                        'attackdamage': 69,
#                        'attackdamageperlevel': 4.2,
#                        'attackrange': 125,
#                        'attackspeed': 0.625,
#                        'attackspeedperlevel': 1.44,
#                        'crit': 0,
#                        'critperlevel': 0,
#                        'hp': 574.4,
#                        'hpperlevel': 80,
#                        'hpregen': 9,
#                        'hpregenperlevel': 0.85,
#                        'movespeed': 345,
#                        'mp': 272.2,
#                        'mpperlevel': 40,
#                        'mpregen': 7.206,
#                        'mpregenperlevel': 0.45,
#                        'spellblock': 32.1,
#                        'spellblockperlevel': 1.25},
#              'tags': ['Tank', 'Mage'],
#              'title': 'the Terror of the Void',
#              'version': '10.14.1'},
#  'Corki': {'blurb': 'The yordle pilot Corki loves two things above all others: '
#                     'flying, and his glamorous mustache... though not '
#                     'necessarily in that order. After leaving Bandle City, he '
#                     'settled in Piltover and fell in love with the wondrous '
#                     'machines he found there. He...',
#            'id': 'Corki',
#            'image': {'full': 'Corki.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion0.png',
#                      'w': 48,
#                      'x': 432,
#                      'y': 48},
#            'info': {'attack': 8, 'defense': 3, 'difficulty': 6, 'magic': 6},
#            'key': '42',
#            'name': 'Corki',
#            'partype': 'Mana',
#            'stats': {'armor': 28,
#                      'armorperlevel': 3.5,
#                      'attackdamage': 55,
#                      'attackdamageperlevel': 2.5,
#                      'attackrange': 550,
#                      'attackspeed': 0.638,
#                      'attackspeedperlevel': 2.3,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 518,
#                      'hpperlevel': 87,
#                      'hpregen': 5.5,
#                      'hpregenperlevel': 0.55,
#                      'movespeed': 325,
#                      'mp': 350.16,
#                      'mpperlevel': 34,
#                      'mpregen': 7.424,
#                      'mpregenperlevel': 0.55,
#                      'spellblock': 30,
#                      'spellblockperlevel': 0.5},
#            'tags': ['Marksman'],
#            'title': 'the Daring Bombardier',
#            'version': '10.14.1'},
#  'Darius': {'blurb': 'There is no greater symbol of Noxian might than Darius, '
#                      "the nation's most feared and battle-hardened commander. "
#                      'Rising from humble origins to become the Hand of Noxus, '
#                      "he cleaves through the empire's enemies—many of them "
#                      'Noxians themselves. Knowing that...',
#             'id': 'Darius',
#             'image': {'full': 'Darius.png',
#                       'group': 'champion',
#                       'h': 48,
#                       'sprite': 'champion0.png',
#                       'w': 48,
#                       'x': 0,
#                       'y': 96},
#             'info': {'attack': 9, 'defense': 5, 'difficulty': 2, 'magic': 1},
#             'key': '122',
#             'name': 'Darius',
#             'partype': 'Mana',
#             'stats': {'armor': 39,
#                       'armorperlevel': 4,
#                       'attackdamage': 64,
#                       'attackdamageperlevel': 5,
#                       'attackrange': 175,
#                       'attackspeed': 0.625,
#                       'attackspeedperlevel': 1,
#                       'crit': 0,
#                       'critperlevel': 0,
#                       'hp': 582.24,
#                       'hpperlevel': 100,
#                       'hpregen': 10,
#                       'hpregenperlevel': 0.95,
#                       'movespeed': 340,
#                       'mp': 263,
#                       'mpperlevel': 37.5,
#                       'mpregen': 6.6,
#                       'mpregenperlevel': 0.35,
#                       'spellblock': 32.1,
#                       'spellblockperlevel': 1.25},
#             'tags': ['Fighter', 'Tank'],
#             'title': 'the Hand of Noxus',
#             'version': '10.14.1'},
#  'Diana': {'blurb': 'Bearing her crescent moonblade, Diana fights as a warrior '
#                     'of the Lunari—a faith all but quashed in the lands around '
#                     'Mount Targon. Clad in shimmering armor the color of '
#                     'winter snow at night, she is a living embodiment of the '
#                     "silver moon's power. Imbued...",
#            'id': 'Diana',
#            'image': {'full': 'Diana.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion0.png',
#                      'w': 48,
#                      'x': 48,
#                      'y': 96},
#            'info': {'attack': 7, 'defense': 6, 'difficulty': 4, 'magic': 8},
#            'key': '131',
#            'name': 'Diana',
#            'partype': 'Mana',
#            'stats': {'armor': 31,
#                      'armorperlevel': 3.6,
#                      'attackdamage': 57,
#                      'attackdamageperlevel': 3,
#                      'attackrange': 150,
#                      'attackspeed': 0.625,
#                      'attackspeedperlevel': 2.25,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 570,
#                      'hpperlevel': 95,
#                      'hpregen': 7.5,
#                      'hpregenperlevel': 0.85,
#                      'movespeed': 345,
#                      'mp': 375,
#                      'mpperlevel': 25,
#                      'mpregen': 8,
#                      'mpregenperlevel': 0.8,
#                      'spellblock': 32.1,
#                      'spellblockperlevel': 1.25},
#            'tags': ['Fighter', 'Mage'],
#            'title': 'Scorn of the Moon',
#            'version': '10.14.1'},
#  'DrMundo': {'blurb': 'Utterly insane, unrepentantly homicidal, and '
#                       'horrifyingly purple, Dr. Mundo is what keeps many of '
#                       "Zaun's citizens indoors on particularly dark nights. "
#                       'This monosyllabic monstrosity seems to want nothing '
#                       'more than pain—both the giving of it, and the...',
#              'id': 'DrMundo',
#              'image': {'full': 'DrMundo.png',
#                        'group': 'champion',
#                        'h': 48,
#                        'sprite': 'champion0.png',
#                        'w': 48,
#                        'x': 144,
#                        'y': 96},
#              'info': {'attack': 5, 'defense': 7, 'difficulty': 5, 'magic': 6},
#              'key': '36',
#              'name': 'Dr. Mundo',
#              'partype': 'None',
#              'stats': {'armor': 36,
#                        'armorperlevel': 3.5,
#                        'attackdamage': 61.27,
#                        'attackdamageperlevel': 3.5,
#                        'attackrange': 125,
#                        'attackspeed': 0.721,
#                        'attackspeedperlevel': 2.8,
#                        'crit': 0,
#                        'critperlevel': 0,
#                        'hp': 582.52,
#                        'hpperlevel': 89,
#                        'hpregen': 8,
#                        'hpregenperlevel': 0.75,
#                        'movespeed': 345,
#                        'mp': 0,
#                        'mpperlevel': 0,
#                        'mpregen': 0,
#                        'mpregenperlevel': 0,
#                        'spellblock': 32.1,
#                        'spellblockperlevel': 1.25},
#              'tags': ['Fighter', 'Tank'],
#              'title': 'the Madman of Zaun',
#              'version': '10.14.1'},
#  'Draven': {'blurb': 'In Noxus, warriors known as Reckoners face one another '
#                      'in arenas where blood is spilled and strength tested—but '
#                      'none has ever been as celebrated as Draven. A former '
#                      'soldier, he found that the crowds uniquely appreciated '
#                      'his flair for the dramatic, and...',
#             'id': 'Draven',
#             'image': {'full': 'Draven.png',
#                       'group': 'champion',
#                       'h': 48,
#                       'sprite': 'champion0.png',
#                       'w': 48,
#                       'x': 96,
#                       'y': 96},
#             'info': {'attack': 9, 'defense': 3, 'difficulty': 8, 'magic': 1},
#             'key': '119',
#             'name': 'Draven',
#             'partype': 'Mana',
#             'stats': {'armor': 29,
#                       'armorperlevel': 3.3,
#                       'attackdamage': 60,
#                       'attackdamageperlevel': 3.61,
#                       'attackrange': 550,
#                       'attackspeed': 0.679,
#                       'attackspeedperlevel': 2.7,
#                       'crit': 0,
#                       'critperlevel': 0,
#                       'hp': 605,
#                       'hpperlevel': 90,
#                       'hpregen': 3.75,
#                       'hpregenperlevel': 0.7,
#                       'movespeed': 330,
#                       'mp': 360.56,
#                       'mpperlevel': 39,
#                       'mpregen': 8.042,
#                       'mpregenperlevel': 0.65,
#                       'spellblock': 30,
#                       'spellblockperlevel': 0.5},
#             'tags': ['Marksman'],
#             'title': 'the Glorious Executioner',
#             'version': '10.14.1'},
#  'Ekko': {'blurb': 'A prodigy from the rough streets of Zaun, Ekko manipulates '
#                    'time to twist any situation to his advantage. Using his '
#                    'own invention, the Zero Drive, he explores the branching '
#                    'possibilities of reality to craft the perfect moment. '
#                    'Though he revels in this...',
#           'id': 'Ekko',
#           'image': {'full': 'Ekko.png',
#                     'group': 'champion',
#                     'h': 48,
#                     'sprite': 'champion0.png',
#                     'w': 48,
#                     'x': 192,
#                     'y': 96},
#           'info': {'attack': 5, 'defense': 3, 'difficulty': 8, 'magic': 7},
#           'key': '245',
#           'name': 'Ekko',
#           'partype': 'Mana',
#           'stats': {'armor': 32,
#                     'armorperlevel': 3,
#                     'attackdamage': 58,
#                     'attackdamageperlevel': 3,
#                     'attackrange': 125,
#                     'attackspeed': 0.688,
#                     'attackspeedperlevel': 3.3,
#                     'crit': 0,
#                     'critperlevel': 0,
#                     'hp': 585,
#                     'hpperlevel': 85,
#                     'hpregen': 9,
#                     'hpregenperlevel': 0.9,
#                     'movespeed': 340,
#                     'mp': 280,
#                     'mpperlevel': 50,
#                     'mpregen': 7,
#                     'mpregenperlevel': 0.8,
#                     'spellblock': 32,
#                     'spellblockperlevel': 1.25},
#           'tags': ['Assassin', 'Fighter'],
#           'title': 'the Boy Who Shattered Time',
#           'version': '10.14.1'},
#  'Elise': {'blurb': 'Elise is a deadly predator who dwells in a shuttered, '
#                     'lightless palace, deep within the oldest city of Noxus. '
#                     'Once mortal, she was the mistress of a powerful house, '
#                     'but the bite of a vile demigod transformed her into '
#                     'something beautiful, yet utterly...',
#            'id': 'Elise',
#            'image': {'full': 'Elise.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion0.png',
#                      'w': 48,
#                      'x': 240,
#                      'y': 96},
#            'info': {'attack': 6, 'defense': 5, 'difficulty': 9, 'magic': 7},
#            'key': '60',
#            'name': 'Elise',
#            'partype': 'Mana',
#            'stats': {'armor': 27,
#                      'armorperlevel': 3.35,
#                      'attackdamage': 55,
#                      'attackdamageperlevel': 3,
#                      'attackrange': 550,
#                      'attackspeed': 0.625,
#                      'attackspeedperlevel': 1.75,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 534,
#                      'hpperlevel': 93,
#                      'hpregen': 5.5,
#                      'hpregenperlevel': 0.6,
#                      'movespeed': 330,
#                      'mp': 324,
#                      'mpperlevel': 50,
#                      'mpregen': 6,
#                      'mpregenperlevel': 0.8,
#                      'spellblock': 30,
#                      'spellblockperlevel': 0.5},
#            'tags': ['Mage', 'Fighter'],
#            'title': 'the Spider Queen',
#            'version': '10.14.1'},
#  'Evelynn': {'blurb': 'Within the dark seams of Runeterra, the demon Evelynn '
#                       'searches for her next victim. She lures in prey with '
#                       'the voluptuous façade of a human female, but once a '
#                       "person succumbs to her charms, Evelynn's true form is "
#                       'unleashed. She then subjects her victim...',
#              'id': 'Evelynn',
#              'image': {'full': 'Evelynn.png',
#                        'group': 'champion',
#                        'h': 48,
#                        'sprite': 'champion0.png',
#                        'w': 48,
#                        'x': 288,
#                        'y': 96},
#              'info': {'attack': 4, 'defense': 2, 'difficulty': 10, 'magic': 7},
#              'key': '28',
#              'name': 'Evelynn',
#              'partype': 'Mana',
#              'stats': {'armor': 37,
#                        'armorperlevel': 3.5,
#                        'attackdamage': 61,
#                        'attackdamageperlevel': 3,
#                        'attackrange': 125,
#                        'attackspeed': 0.667,
#                        'attackspeedperlevel': 2.1,
#                        'crit': 0,
#                        'critperlevel': 0,
#                        'hp': 572,
#                        'hpperlevel': 84,
#                        'hpregen': 8.5,
#                        'hpregenperlevel': 0.75,
#                        'movespeed': 335,
#                        'mp': 315.6,
#                        'mpperlevel': 42,
# ...
#                        'critperlevel': 0,
#                        'hp': 570,
#                        'hpperlevel': 92,
#                        'hpregen': 8,
#                        'hpregenperlevel': 0.7,
#                        'movespeed': 345,
#                        'mp': 273.8,
#                        'mpperlevel': 35,
#                        'mpregen': 7.256,
#                        'mpregenperlevel': 0.45,
#                        'spellblock': 32.1,
#                        'spellblockperlevel': 1.25},
#              'tags': ['Fighter', 'Assassin'],
#              'title': 'the Seneschal of Demacia',
#              'version': '10.14.1'},
#  'Yasuo': {'blurb': 'An Ionian of deep resolve, Yasuo is an agile swordsman '
#                     'who wields the air itself against his enemies. As a proud '
#                     'young man, he was falsely accused of murdering his '
#                     'master—unable to prove his innocence, he was forced to '
#                     'slay his own brother in self...',
#            'id': 'Yasuo',
#            'image': {'full': 'Yasuo.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion4.png',
#                      'w': 48,
#                      'x': 432,
#                      'y': 48},
#            'info': {'attack': 8, 'defense': 4, 'difficulty': 10, 'magic': 4},
#            'key': '157',
#            'name': 'Yasuo',
#            'partype': 'Flow',
#            'stats': {'armor': 30,
#                      'armorperlevel': 3.4,
#                      'attackdamage': 60,
#                      'attackdamageperlevel': 3.2,
#                      'attackrange': 175,
#                      'attackspeed': 0.697,
#                      'attackspeedperlevel': 2.5,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 490,
#                      'hpperlevel': 87,
#                      'hpregen': 6.5,
#                      'hpregenperlevel': 0.9,
#                      'movespeed': 345,
#                      'mp': 100,
#                      'mpperlevel': 0,
#                      'mpregen': 0,
#                      'mpregenperlevel': 0,
#                      'spellblock': 30,
#                      'spellblockperlevel': 1.25},
#            'tags': ['Fighter', 'Assassin'],
#            'title': 'the Unforgiven',
#            'version': '10.14.1'},
#  'Yorick': {'blurb': 'The last survivor of a long-forgotten religious order, '
#                      'Yorick is both blessed and cursed with power over the '
#                      'dead. Trapped on the Shadow Isles, his only companions '
#                      'are the rotting corpses and shrieking spirits that he '
#                      "gathers to him. Yorick's monstrous...",
#             'id': 'Yorick',
#             'image': {'full': 'Yorick.png',
#                       'group': 'champion',
#                       'h': 48,
#                       'sprite': 'champion4.png',
#                       'w': 48,
#                       'x': 0,
#                       'y': 96},
#             'info': {'attack': 6, 'defense': 6, 'difficulty': 6, 'magic': 4},
#             'key': '83',
#             'name': 'Yorick',
#             'partype': 'Mana',
#             'stats': {'armor': 39,
#                       'armorperlevel': 4,
#                       'attackdamage': 62,
#                       'attackdamageperlevel': 5,
#                       'attackrange': 175,
#                       'attackspeed': 0.625,
#                       'attackspeedperlevel': 2,
#                       'crit': 0,
#                       'critperlevel': 0,
#                       'hp': 580,
#                       'hpperlevel': 100,
#                       'hpregen': 8,
#                       'hpregenperlevel': 0.8,
#                       'movespeed': 340,
#                       'mp': 300,
#                       'mpperlevel': 40,
#                       'mpregen': 7.5,
#                       'mpregenperlevel': 0.75,
#                       'spellblock': 32,
#                       'spellblockperlevel': 1.25},
#             'tags': ['Fighter', 'Tank'],
#             'title': 'Shepherd of Souls',
#             'version': '10.14.1'},
#  'Yuumi': {'blurb': 'A magical cat from Bandle City, Yuumi was once the '
#                     'familiar of a yordle enchantress, Norra. When her master '
#                     'mysteriously disappeared, Yuumi became the Keeper of '
#                     "Norra's sentient Book of Thresholds, traveling through "
#                     'portals in its pages to search for...',
#            'id': 'Yuumi',
#            'image': {'full': 'Yuumi.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion4.png',
#                      'w': 48,
#                      'x': 48,
#                      'y': 96},
#            'info': {'attack': 5, 'defense': 1, 'difficulty': 2, 'magic': 8},
#            'key': '350',
#            'name': 'Yuumi',
#            'partype': 'Mana',
#            'stats': {'armor': 25,
#                      'armorperlevel': 3,
#                      'attackdamage': 55,
#                      'attackdamageperlevel': 3.1,
#                      'attackrange': 500,
#                      'attackspeed': 0.625,
#                      'attackspeedperlevel': 1,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 480,
#                      'hpperlevel': 70,
#                      'hpregen': 7,
#                      'hpregenperlevel': 0.55,
#                      'movespeed': 330,
#                      'mp': 400,
#                      'mpperlevel': 45,
#                      'mpregen': 10,
#                      'mpregenperlevel': 0.4,
#                      'spellblock': 25,
#                      'spellblockperlevel': 0.3},
#            'tags': ['Support', 'Mage'],
#            'title': 'the Magical Cat',
#            'version': '10.14.1'},
#  'Zac': {'blurb': 'Zac is the product of a toxic spill that ran through a '
#                   'chemtech seam and pooled in an isolated cavern deep in '
#                   "Zaun's Sump. Despite such humble origins, Zac has grown "
#                   'from primordial ooze into a thinking being who dwells in '
#                   "the city's pipes, occasionally...",
#          'id': 'Zac',
#          'image': {'full': 'Zac.png',
#                    'group': 'champion',
#                    'h': 48,
#                    'sprite': 'champion4.png',
#                    'w': 48,
#                    'x': 96,
#                    'y': 96},
#          'info': {'attack': 3, 'defense': 7, 'difficulty': 8, 'magic': 7},
#          'key': '154',
#          'name': 'Zac',
#          'partype': 'None',
#          'stats': {'armor': 33,
#                    'armorperlevel': 3.5,
#                    'attackdamage': 60,
#                    'attackdamageperlevel': 3.4,
#                    'attackrange': 175,
#                    'attackspeed': 0.736,
#                    'attackspeedperlevel': 1.6,
#                    'crit': 0,
#                    'critperlevel': 0,
#                    'hp': 615,
#                    'hpperlevel': 95,
#                    'hpregen': 8,
#                    'hpregenperlevel': 0.5,
#                    'movespeed': 340,
#                    'mp': 0,
#                    'mpperlevel': 0,
#                    'mpregen': 0,
#                    'mpregenperlevel': 0,
#                    'spellblock': 32,
#                    'spellblockperlevel': 1.25},
#          'tags': ['Tank', 'Fighter'],
#          'title': 'the Secret Weapon',
#          'version': '10.14.1'},
#  'Zed': {'blurb': 'Utterly ruthless and without mercy, Zed is the leader of '
#                   'the Order of Shadow, an organization he created with the '
#                   "intent of militarizing Ionia's magical and martial "
#                   'traditions to drive out Noxian invaders. During the war, '
#                   'desperation led him to unlock...',
#          'id': 'Zed',
#          'image': {'full': 'Zed.png',
#                    'group': 'champion',
#                    'h': 48,
#                    'sprite': 'champion4.png',
#                    'w': 48,
#                    'x': 144,
#                    'y': 96},
#          'info': {'attack': 9, 'defense': 2, 'difficulty': 7, 'magic': 1},
#          'key': '238',
#          'name': 'Zed',
#          'partype': 'Energy',
#          'stats': {'armor': 32,
#                    'armorperlevel': 3.5,
#                    'attackdamage': 63,
#                    'attackdamageperlevel': 3.4,
#                    'attackrange': 125,
#                    'attackspeed': 0.651,
#                    'attackspeedperlevel': 3.3,
#                    'crit': 0,
#                    'critperlevel': 0,
#                    'hp': 584,
#                    'hpperlevel': 85,
#                    'hpregen': 7,
#                    'hpregenperlevel': 0.65,
#                    'movespeed': 345,
#                    'mp': 200,
#                    'mpperlevel': 0,
#                    'mpregen': 50,
#                    'mpregenperlevel': 0,
#                    'spellblock': 32.1,
#                    'spellblockperlevel': 1.25},
#          'tags': ['Assassin'],
#          'title': 'the Master of Shadows',
#          'version': '10.14.1'},
#  'Ziggs': {'blurb': 'With a love of big bombs and short fuses, the yordle '
#                     "Ziggs is an explosive force of nature. As an inventor's "
#                     'assistant in Piltover, he was bored by his predictable '
#                     'life and befriended a mad, blue-haired bomber named Jinx. '
#                     'After a wild night on the town...',
#            'id': 'Ziggs',
#            'image': {'full': 'Ziggs.png',
#                      'group': 'champion',
#                      'h': 48,
#                      'sprite': 'champion4.png',
#                      'w': 48,
#                      'x': 192,
#                      'y': 96},
#            'info': {'attack': 2, 'defense': 4, 'difficulty': 4, 'magic': 9},
#            'key': '115',
#            'name': 'Ziggs',
#            'partype': 'Mana',
#            'stats': {'armor': 21.544,
#                      'armorperlevel': 3.3,
#                      'attackdamage': 54.208,
#                      'attackdamageperlevel': 3.1,
#                      'attackrange': 550,
#                      'attackspeed': 0.656,
#                      'attackspeedperlevel': 2,
#                      'crit': 0,
#                      'critperlevel': 0,
#                      'hp': 536,
#                      'hpperlevel': 92,
#                      'hpregen': 6.5,
#                      'hpregenperlevel': 0.6,
#                      'movespeed': 325,
#                      'mp': 480,
#                      'mpperlevel': 23.5,
#                      'mpregen': 8,
#                      'mpregenperlevel': 0.8,
#                      'spellblock': 30,
#                      'spellblockperlevel': 0.5},
#            'tags': ['Mage'],
#            'title': 'the Hexplosives Expert',
#            'version': '10.14.1'},
#  'Zilean': {'blurb': 'Once a powerful Icathian mage, Zilean became obsessed '
#                      "with the passage of time after witnessing his homeland's "
#                      'destruction by the Void. Unable to spare even a minute '
#                      'to grieve the catastrophic loss, he called upon ancient '
#                      'temporal magic to divine all...',
#             'id': 'Zilean',
#             'image': {'full': 'Zilean.png',
#                       'group': 'champion',
#                       'h': 48,
#                       'sprite': 'champion4.png',
#                       'w': 48,
#                       'x': 240,
#                       'y': 96},
#             'info': {'attack': 2, 'defense': 5, 'difficulty': 6, 'magic': 8},
#             'key': '26',
#             'name': 'Zilean',
#             'partype': 'Mana',
#             'stats': {'armor': 24,
#                       'armorperlevel': 3.8,
#                       'attackdamage': 51.64,
#                       'attackdamageperlevel': 3,
#                       'attackrange': 550,
#                       'attackspeed': 0.625,
#                       'attackspeedperlevel': 2.13,
#                       'crit': 0,
#                       'critperlevel': 0,
#                       'hp': 504,
#                       'hpperlevel': 82,
#                       'hpregen': 5.5,
#                       'hpregenperlevel': 0.5,
#                       'movespeed': 335,
#                       'mp': 452,
#                       'mpperlevel': 30,
#                       'mpregen': 11.335,
#                       'mpregenperlevel': 0.8,
#                       'spellblock': 30,
#                       'spellblockperlevel': 0.5},
#             'tags': ['Support', 'Mage'],
#             'title': 'the Chronokeeper',
#             'version': '10.14.1'},
#  'Zoe': {'blurb': 'As the embodiment of mischief, imagination, and change, Zoe '
#                   'acts as the cosmic messenger of Targon, heralding major '
#                   'events that reshape worlds. Her mere presence warps the '
#                   'arcane mathematics governing realities, sometimes causing '
#                   'cataclysms without...',
#          'id': 'Zoe',
#          'image': {'full': 'Zoe.png',
#                    'group': 'champion',
#                    'h': 48,
#                    'sprite': 'champion4.png',
#                    'w': 48,
#                    'x': 288,
#                    'y': 96},
#          'info': {'attack': 1, 'defense': 7, 'difficulty': 5, 'magic': 8},
#          'key': '142',
#          'name': 'Zoe',
#          'partype': 'Mana',
#          'stats': {'armor': 20.8,
#                    'armorperlevel': 3.5,
#                    'attackdamage': 58,
#                    'attackdamageperlevel': 3.3,
#                    'attackrange': 550,
#                    'attackspeed': 0.625,
#                    'attackspeedperlevel': 2.5,
#                    'crit': 0,
#                    'critperlevel': 0,
#                    'hp': 560,
#                    'hpperlevel': 92,
#                    'hpregen': 6.5,
#                    'hpregenperlevel': 0.6,
#                    'movespeed': 340,
#                    'mp': 425,
#                    'mpperlevel': 25,
#                    'mpregen': 8,
#                    'mpregenperlevel': 0.65,
#                    'spellblock': 30,
#                    'spellblockperlevel': 0.5},
#          'tags': ['Mage', 'Support'],
#          'title': 'the Aspect of Twilight',
#          'version': '10.14.1'},
#  'Zyra': {'blurb': 'Born in an ancient, sorcerous catastrophe, Zyra is the '
#                    'wrath of nature given form—an alluring hybrid of plant and '
#                    'human, kindling new life with every step. She views the '
#                    'many mortals of Valoran as little more than prey for her '
#                    'seeded progeny, and thinks...',
#           'id': 'Zyra',
#           'image': {'full': 'Zyra.png',
#                     'group': 'champion',
#                     'h': 48,
#                     'sprite': 'champion4.png',
#                     'w': 48,
#                     'x': 336,
#                     'y': 96},
#           'info': {'attack': 4, 'defense': 3, 'difficulty': 7, 'magic': 8},
#           'key': '143',
#           'name': 'Zyra',
#           'partype': 'Mana',
#           'stats': {'armor': 29,
#                     'armorperlevel': 3,
#                     'attackdamage': 53.376,
#                     'attackdamageperlevel': 3.2,
#                     'attackrange': 575,
#                     'attackspeed': 0.625,
#                     'attackspeedperlevel': 2.11,
#                     'crit': 0,
#                     'critperlevel': 0,
#                     'hp': 504,
#                     'hpperlevel': 79,
#                     'hpregen': 5.5,
#                     'hpregenperlevel': 0.5,
#                     'movespeed': 340,
#                     'mp': 418,
#                     'mpperlevel': 25,
#                     'mpregen': 13,
#                     'mpregenperlevel': 0.4,
#                     'spellblock': 30,
#                     'spellblockperlevel': 0.5},
#           'tags': ['Mage', 'Support'],
#           'title': 'Rise of the Thorns',
#           'version': '10.14.1'}}

# %%
## Creates dictionary of champion id to champion name
champion_names = champion_data['data'].keys()
ids = [champion_data['data'][champion]['key'] for champion in champion_names]
ids = list(map(int, ids))
champion_id_dict = dict(zip(ids, champion_names))
pprint.pprint(champion_id_dict)
# Out:
# {1: 'Annie',
#  2: 'Olaf',
#  3: 'Galio',
#  4: 'TwistedFate',
#  5: 'XinZhao',
#  6: 'Urgot',
#  7: 'Leblanc',
#  8: 'Vladimir',
#  9: 'Fiddlesticks',
#  10: 'Kayle',
#  11: 'MasterYi',
#  12: 'Alistar',
#  13: 'Ryze',
#  14: 'Sion',
#  15: 'Sivir',
#  16: 'Soraka',
#  17: 'Teemo',
#  18: 'Tristana',
#  19: 'Warwick',
#  20: 'Nunu',
#  21: 'MissFortune',
#  22: 'Ashe',
#  23: 'Tryndamere',
#  24: 'Jax',
#  25: 'Morgana',
#  26: 'Zilean',
#  27: 'Singed',
#  28: 'Evelynn',
#  29: 'Twitch',
#  30: 'Karthus',
#  31: 'Chogath',
#  32: 'Amumu',
#  33: 'Rammus',
#  34: 'Anivia',
#  35: 'Shaco',
#  36: 'DrMundo',
#  37: 'Sona',
#  38: 'Kassadin',
#  39: 'Irelia',
#  40: 'Janna',
#  41: 'Gangplank',
#  42: 'Corki',
#  43: 'Karma',
#  44: 'Taric',
#  45: 'Veigar',
#  48: 'Trundle',
#  50: 'Swain',
#  51: 'Caitlyn',
#  53: 'Blitzcrank',
#  54: 'Malphite',
#  55: 'Katarina',
#  56: 'Nocturne',
#  57: 'Maokai',
#  58: 'Renekton',
#  59: 'JarvanIV',
#  60: 'Elise',
#  61: 'Orianna',
#  62: 'MonkeyKing',
#  63: 'Brand',
#  64: 'LeeSin',
#  67: 'Vayne',
#  68: 'Rumble',
#  69: 'Cassiopeia',
#  72: 'Skarner',
#  74: 'Heimerdinger',
#  75: 'Nasus',
#  76: 'Nidalee',
#  77: 'Udyr',
#  78: 'Poppy',
#  79: 'Gragas',
#  80: 'Pantheon',
#  81: 'Ezreal',
#  82: 'Mordekaiser',
#  83: 'Yorick',
#  84: 'Akali',
#  85: 'Kennen',
#  86: 'Garen',
#  89: 'Leona',
#  90: 'Malzahar',
#  91: 'Talon',
#  92: 'Riven',
#  96: 'KogMaw',
#  98: 'Shen',
#  99: 'Lux',
#  101: 'Xerath',
#  102: 'Shyvana',
#  103: 'Ahri',
#  104: 'Graves',
#  105: 'Fizz',
#  106: 'Volibear',
#  107: 'Rengar',
#  110: 'Varus',
#  111: 'Nautilus',
#  112: 'Viktor',
#  113: 'Sejuani',
#  114: 'Fiora',
#  115: 'Ziggs',
#  117: 'Lulu',
#  119: 'Draven',
#  120: 'Hecarim',
#  121: 'Khazix',
#  122: 'Darius',
#  126: 'Jayce',
#  127: 'Lissandra',
#  131: 'Diana',
#  133: 'Quinn',
#  134: 'Syndra',
#  136: 'AurelionSol',
#  141: 'Kayn',
#  142: 'Zoe',
#  143: 'Zyra',
#  145: 'Kaisa',
#  150: 'Gnar',
#  154: 'Zac',
#  157: 'Yasuo',
#  161: 'Velkoz',
#  163: 'Taliyah',
#  164: 'Camille',
#  201: 'Braum',
#  202: 'Jhin',
#  203: 'Kindred',
#  222: 'Jinx',
#  223: 'TahmKench',
#  235: 'Senna',
#  236: 'Lucian',
#  238: 'Zed',
#  240: 'Kled',
#  245: 'Ekko',
#  246: 'Qiyana',
#  254: 'Vi',
#  266: 'Aatrox',
#  267: 'Nami',
#  268: 'Azir',
#  350: 'Yuumi',
#  412: 'Thresh',
#  420: 'Illaoi',
#  421: 'RekSai',
#  427: 'Ivern',
#  429: 'Kalista',
#  432: 'Bard',
#  497: 'Rakan',
#  498: 'Xayah',
#  516: 'Ornn',
#  517: 'Sylas',
#  518: 'Neeko',
#  523: 'Aphelios',
#  555: 'Pyke',
#  875: 'Sett'}

# %%
# Remapping champion ids of the dataframe to champion names from dictionary

s_str = "participants_"
e_str = "_championId"
i = 0
for i in range(0,10):
    key = s_str + str(i) + e_str
    df = df.replace({key : champion_id_dict})

# %% [markdown]
# # regex + participants

# %%
import re

# %%
def strippart(num):
    res = []
    for name in df.columns:
        if re.search('^participants_{}_'.format(num), name) != None:
            res += [name]
    res = [re.sub('^participants_{}_'.format(num), '', x) for x in res]
    return res

# %%
f0 = set(strippart(0))
f1 = set(strippart(1))
f2 = set(strippart(2))
f3 = set(strippart(3))
f4 = set(strippart(4))
f5 = set(strippart(5))
f6 = set(strippart(6))
f7 = set(strippart(7))
f8 = set(strippart(8))
f9 = set(strippart(9))

# %%
len(f0),len(f1),len(f2),len(f3),len(f4),len(f5),len(f6),len(f7),len(f8),len(f9)
# Out:
# (109, 106, 106, 106, 108, 106, 105, 107, 107, 107)

# %%
set([x for x in f0 if 'playerScore' not in x])-f4
# Out:
# set()

# %%
common = list(f0 & f1 & f2 & f3 & f4 & f5 & f6 & f7 & f8 & f9)

# %%
len(common)
# Out:
# 105

# %%
start = list(df.columns[:5])

team = []
for name in df.columns:
    if re.search('^team', name) != None:
        team += [name]

playercol = ['player_platformId', 'player_accountId', 'player_summonerName', 'player_summonerId', 
          'currentAccountId', 'player_matchHistoryUri', 'player_profileIcon']

partid = []
for name in df.columns:
    if re.search('^participantIdentities', name) != None:
        partid += [name]

def isolate(num):
    participant = ['participants_{}_{}'.format(num,x) for x in common]
    player = [x for x in partid if str(num) in x]
    res = df.copy()[start + team + participant + player]
    newcol = start + team + common + playercol
    res.columns = newcol
    res['participant_number'] = num
    return res

# %%
i0 = isolate(0)
i1 = isolate(1)
i2 = isolate(2)
i3 = isolate(3)
i4 = isolate(4)
i5 = isolate(5)
i6 = isolate(6)
i7 = isolate(7)
i8 = isolate(8)
i9 = isolate(9)

# %%
participants = pd.concat([i0,i1,i2,i3,i4,i5,i6,i7,i8,i9])
participants.shape
# Out:
# (294730, 162)

# %%
participants
# Out:
#            gameId   gameCreation  gameDuration  queueId     gameVersion  \
# 0      3425927177  1589811429884          1548      420  10.10.320.3039
# 1      3463315468  1592285561264          1499      420  10.12.324.5925
# 2      3490775054  1594487307024          2300      420  10.14.327.8505
# 3      3449782290  1591330333433          1413      420  10.11.322.2991
# 4      3482451986  1593821192664          1608      420  10.13.326.4870
# ...           ...            ...           ...      ...             ...
# 29468  3487563744  1594224435270          1549      420  10.14.327.1684
# 29469  3480158177  1593634490053           762      420  10.13.326.4870
# 29470  3326738405  1584385654501          1407      420    10.5.312.392
# 29471  3479175144  1593561996811          2128      420  10.13.326.4870
# 29472  3310223355  1582941398165          1172      420   10.4.308.9400
#
#        teams_0_win  teams_0_firstBlood  teams_0_firstTower  \
# 0                1                   1                   1
# 1                0                   0                   0
# 2                0                   0                   1
# 3                0                   1                   0
# 4                1                   1                   0
# ...            ...                 ...                 ...
# 29468            1                   1                   0
# 29469            1                   0                   1
# 29470            1                   1                   1
# 29471            1                   0                   0
# 29472            0                   1                   0
#
#        teams_0_firstInhibitor  teams_0_firstBaron  ...  \
# 0                           1                   1  ...
# 1                           0                   0  ...
# 2                           0                   1  ...
# 3                           0                   0  ...
# 4                           1                   1  ...
# ...                       ...                 ...  ...
# 29468                       1                   1  ...
# 29469                       1                   0  ...
# 29470                       1                   1  ...
# 29471                       1                   0  ...
# 29472                       0                   0  ...
#
#        timeline_creepsPerMinDeltas_0-10  stats_goldSpent  player_platformId  \
# 0                                   7.2            13425                NA1
# 1                                   9.0             8358                NA1
# 2                                   0.3            13260                NA1
# 3                                   6.9             9400                NA1
# 4                                   6.9            11400                NA1
# ...                                 ...              ...                ...
# 29468                               8.2             7383                NA1
# 29469                               0.6              975                NA1
# 29470                               0.1             5950                NA1
# 29471                               0.4             9625                  0
# 29472                               0.5             6975                NA1
#
#                                         player_accountId  player_summonerName  \
# 0         HdSEE_2_wJd3FOo1t1GzHaqn_fEBA3ogvWV4XkHqhB5T4Q              Saiyans
# 1      BUGcEEv-l4OFWCoKxcqTRiJm2P90ToFAs-jJNG5XXC63yI...        watch clannad
# 2      qg0OpXGX86H4EcgT8n66VueND9Ny1MZiweQwWz9VuZtRVp...                timal
# 3      KLpPTF9mA2fmvDeV2YV3VPAHzetDhq-S5yruLosYLHL61M...             lMT Eika
# 4      wxbYpmkHf9DVZOBF_yhcoF2pPZ9cEkHyRG602B7wrTByC_...      malahuoguo fans
# ...                                                  ...                  ...
# 29468    98ECGhIuA8Q6OuacZBoFiGHxP3Y21IcvVk8xlbDklXCzR9U               Dumahl
# 29469  WJEJ5P6XqTQakJNiRK6gz6I7X46w8DcbtkD2K71tPY1bdF...          James Jeong
# 29470     iT86RgwVfyVpoVE87GJqeeEV9nr2esvQ0K5fLp7Gii0AqQ     ttvMemeLibrarian
# 29471     HzNJg2zlU_YKZAzbLfzrLHbLYgAjL2kiEDdOyH0cRE78WA            Prabhably
# 29472    Zw1MU_o_qJls9jNjZ_tYh2wk6DR378Uw5hoRxI9zNfmW_rk                Naeun
#
#                                       player_summonerId  \
# 0       slg_XD264Tf5OPLTFtklRkXBevhsx2M1soipEFA-NBTtDUU
# 1      oBd4V3pA5V1hOBVyRDSj9OC_myutNzv-wyARZ5IyvFtnXyFI
# 2      Coeuu_2hrEWEJfgVd9ppv5sbZsH2B3coK4yl0aDPuHvWXpKV
# 3      7yVhyCE7BXDw_VVWxEsuQbgMj_GjsVg5_Duq6ZZA4zpF8sUE
# 4      AjNo8fDBrQHVAmkcAjTVlsqBdOuaJJPlZuqnoyc4UT5P8RqD
# ...                                                 ...
# 29468   4BfwEx0sWzbooDAAlwSawkRSgw8nW2XxCPjs0W6oHOSYCEg
# 29469   IGC5QF4xMiAU8qqEIELHzsFhri0cy7GA7o8WuBzzOwvPjPg
# 29470   _cL5jlhxAqL82PLXxh8S8VLaRptlpQyxeuI4XU81NCMUm3k
# 29471   nQZnVuE_FGMWS6QlfuPFKY1juDTedohndkmaBvvUm6OlTAU
# 29472   jC63bM_IaGPgDJPBgHqhbjjJroHhdwaGbJ8TZiIffVDfPE0
#
#                                         currentAccountId  \
# 0         HdSEE_2_wJd3FOo1t1GzHaqn_fEBA3ogvWV4XkHqhB5T4Q
# 1      BUGcEEv-l4OFWCoKxcqTRiJm2P90ToFAs-jJNG5XXC63yI...
# 2      qg0OpXGX86H4EcgT8n66VueND9Ny1MZiweQwWz9VuZtRVp...
# 3      KLpPTF9mA2fmvDeV2YV3VPAHzetDhq-S5yruLosYLHL61M...
# 4      wxbYpmkHf9DVZOBF_yhcoF2pPZ9cEkHyRG602B7wrTByC_...
# ...                                                  ...
# 29468    98ECGhIuA8Q6OuacZBoFiGHxP3Y21IcvVk8xlbDklXCzR9U
# 29469  WJEJ5P6XqTQakJNiRK6gz6I7X46w8DcbtkD2K71tPY1bdF...
# 29470     iT86RgwVfyVpoVE87GJqeeEV9nr2esvQ0K5fLp7Gii0AqQ
# 29471     HzNJg2zlU_YKZAzbLfzrLHbLYgAjL2kiEDdOyH0cRE78WA
# 29472    Zw1MU_o_qJls9jNjZ_tYh2wk6DR378Uw5hoRxI9zNfmW_rk
#
#                               player_matchHistoryUri  player_profileIcon  \
# 0              /v1/stats/player_history/NA1/42407804                3002
# 1      /v1/stats/player_history/NA1/2121925252565312                  23
# 2      /v1/stats/player_history/NA1/2252934392023072                4568
# 3      /v1/stats/player_history/NA1/2378839681460352                3478
# 4      /v1/stats/player_history/NA1/2471543443835776                  29
# ...                                              ...                 ...
# 29468         /v1/stats/player_history/NA1/236562517                3791
# 29469  /v1/stats/player_history/NA1/1999549387926176                3380
# 29470          /v1/stats/player_history/NA1/50413575                  12
# 29471           /v1/stats/player_history/NA/36062060                  22
# 29472         /v1/stats/player_history/NA1/244055054                1296
#
#        participant_number
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 29468                   9
# 29469                   9
# 29470                   9
# 29471                   9
# 29472                   9
#
# [294730 rows x 162 columns]

# %%
participants.columns
# Out:
# Index(['gameId', 'gameCreation', 'gameDuration', 'queueId', 'gameVersion',
#        'teams_0_win', 'teams_0_firstBlood', 'teams_0_firstTower',
#        'teams_0_firstInhibitor', 'teams_0_firstBaron',
#        ...
#        'timeline_creepsPerMinDeltas_0-10', 'stats_goldSpent',
#        'player_platformId', 'player_accountId', 'player_summonerName',
#        'player_summonerId', 'currentAccountId', 'player_matchHistoryUri',
#        'player_profileIcon', 'participant_number'],
#       dtype='object', length=162)

# %%
compression_opts = dict(method='zip',
                        archive_name='player.csv')  
participants.to_csv('player.zip', index=False, compression=compression_opts)

# %% [markdown]
# # exploration

# %%
# Exploring columns
for name in df.columns:
    print(name)
# Out:
# gameId
# gameCreation
# gameDuration
# queueId
# gameVersion
# teams_0_win
# teams_0_firstBlood
# teams_0_firstTower
# teams_0_firstInhibitor
# teams_0_firstBaron
# teams_0_firstDragon
# teams_0_firstRiftHerald
# teams_0_towerKills
# teams_0_inhibitorKills
# teams_0_baronKills
# teams_0_dragonKills
# teams_0_riftHeraldKills
# teams_1_win
# teams_1_firstBlood
# teams_1_firstTower
# teams_1_firstInhibitor
# teams_1_firstBaron
# teams_1_firstDragon
# teams_1_firstRiftHerald
# teams_1_towerKills
# teams_1_inhibitorKills
# teams_1_baronKills
# teams_1_dragonKills
# teams_1_riftHeraldKills
# participants_0_championId
# participants_0_spell1Id
# participants_0_spell2Id
# participants_0_stats_win
# participants_0_stats_item0
# participants_0_stats_item1
# participants_0_stats_item2
# participants_0_stats_item3
# participants_0_stats_item4
# participants_0_stats_item5
# participants_0_stats_item6
# participants_0_stats_kills
# participants_0_stats_deaths
# participants_0_stats_assists
# participants_0_stats_largestKillingSpree
# participants_0_stats_largestMultiKill
# participants_0_stats_killingSprees
# participants_0_stats_longestTimeSpentLiving
# participants_0_stats_doubleKills
# participants_0_stats_tripleKills
# participants_0_stats_quadraKills
# participants_0_stats_pentaKills
# participants_0_stats_unrealKills
# participants_0_stats_totalDamageDealt
# participants_0_stats_magicDamageDealt
# participants_0_stats_physicalDamageDealt
# participants_0_stats_trueDamageDealt
# participants_0_stats_largestCriticalStrike
# participants_0_stats_totalDamageDealtToChampions
# participants_0_stats_magicDamageDealtToChampions
# participants_0_stats_physicalDamageDealtToChampions
# participants_0_stats_trueDamageDealtToChampions
# participants_0_stats_totalHeal
# participants_0_stats_totalUnitsHealed
# participants_0_stats_damageSelfMitigated
# participants_0_stats_damageDealtToObjectives
# participants_0_stats_damageDealtToTurrets
# participants_0_stats_visionScore
# participants_0_stats_timeCCingOthers
# participants_0_stats_totalDamageTaken
# participants_0_stats_magicalDamageTaken
# participants_0_stats_physicalDamageTaken
# participants_0_stats_trueDamageTaken
# participants_0_stats_goldEarned
# participants_0_stats_goldSpent
# participants_0_stats_turretKills
# participants_0_stats_inhibitorKills
# participants_0_stats_totalMinionsKilled
# participants_0_stats_neutralMinionsKilled
# participants_0_stats_totalTimeCrowdControlDealt
# participants_0_stats_champLevel
# participants_0_stats_visionWardsBoughtInGame
# participants_0_stats_firstBloodKill
# participants_0_stats_firstBloodAssist
# participants_0_stats_firstTowerKill
# participants_0_stats_firstTowerAssist
# participants_0_stats_firstInhibitorKill
# participants_0_stats_firstInhibitorAssist
# participants_0_stats_playerScore2
# participants_0_stats_playerScore4
# participants_0_stats_playerScore6
# participants_0_stats_playerScore7
# participants_0_stats_playerScore8
# participants_0_stats_perk0
# participants_0_stats_perk0Var1
# participants_0_stats_perk0Var2
# participants_0_stats_perk0Var3
# participants_0_stats_perk1
# participants_0_stats_perk1Var1
# participants_0_stats_perk1Var2
# participants_0_stats_perk1Var3
# participants_0_stats_perk2
# participants_0_stats_perk2Var1
# participants_0_stats_perk2Var2
# participants_0_stats_perk2Var3
# participants_0_stats_perk3
# participants_0_stats_perk3Var1
# participants_0_stats_perk3Var2
# participants_0_stats_perk3Var3
# participants_0_stats_perk4
# participants_0_stats_perk4Var1
# participants_0_stats_perk4Var2
# participants_0_stats_perk4Var3
# participants_0_stats_perk5
# participants_0_stats_perk5Var1
# participants_0_stats_perk5Var2
# participants_0_stats_perk5Var3
# participants_0_stats_perkPrimaryStyle
# participants_0_stats_perkSubStyle
# participants_0_stats_statPerk0
# participants_0_stats_statPerk1
# participants_0_stats_statPerk2
# participants_0_timeline_creepsPerMinDeltas_10-20
# participants_0_timeline_creepsPerMinDeltas_0-10
# participants_0_timeline_xpPerMinDeltas_10-20
# participants_0_timeline_xpPerMinDeltas_0-10
# participants_0_timeline_goldPerMinDeltas_10-20
# participants_0_timeline_goldPerMinDeltas_0-10
# participants_0_timeline_damageTakenPerMinDeltas_10-20
# participants_0_timeline_damageTakenPerMinDeltas_0-10
# participants_0_timeline_role
# participants_0_timeline_lane
# participants_1_championId
# participants_1_spell1Id
# participants_1_spell2Id
# participants_1_stats_win
# participants_1_stats_item0
# participants_1_stats_item1
# participants_1_stats_item2
# participants_1_stats_item3
# participants_1_stats_item4
# participants_1_stats_item5
# participants_1_stats_item6
# participants_1_stats_kills
# participants_1_stats_deaths
# participants_1_stats_assists
# participants_1_stats_largestKillingSpree
# participants_1_stats_largestMultiKill
# participants_1_stats_killingSprees
# participants_1_stats_longestTimeSpentLiving
# participants_1_stats_doubleKills
# participants_1_stats_tripleKills
# participants_1_stats_quadraKills
# participants_1_stats_pentaKills
# participants_1_stats_unrealKills
# participants_1_stats_totalDamageDealt
# participants_1_stats_magicDamageDealt
# participants_1_stats_physicalDamageDealt
# participants_1_stats_trueDamageDealt
# participants_1_stats_largestCriticalStrike
# participants_1_stats_totalDamageDealtToChampions
# participants_1_stats_magicDamageDealtToChampions
# participants_1_stats_physicalDamageDealtToChampions
# participants_1_stats_trueDamageDealtToChampions
# participants_1_stats_totalHeal
# participants_1_stats_totalUnitsHealed
# participants_1_stats_damageSelfMitigated
# participants_1_stats_damageDealtToObjectives
# participants_1_stats_damageDealtToTurrets
# participants_1_stats_visionScore
# participants_1_stats_timeCCingOthers
# participants_1_stats_totalDamageTaken
# participants_1_stats_magicalDamageTaken
# participants_1_stats_physicalDamageTaken
# participants_1_stats_trueDamageTaken
# participants_1_stats_goldEarned
# participants_1_stats_goldSpent
# participants_1_stats_turretKills
# participants_1_stats_inhibitorKills
# participants_1_stats_totalMinionsKilled
# participants_1_stats_neutralMinionsKilled
# participants_1_stats_totalTimeCrowdControlDealt
# participants_1_stats_champLevel
# participants_1_stats_visionWardsBoughtInGame
# participants_1_stats_firstBloodKill
# participants_1_stats_firstBloodAssist
# participants_1_stats_firstTowerKill
# participants_1_stats_firstTowerAssist
# participants_1_stats_firstInhibitorKill
# participants_1_stats_firstInhibitorAssist
# participants_1_stats_playerScore6
# participants_1_stats_playerScore7
# participants_1_stats_perk0
# participants_1_stats_perk0Var1
# participants_1_stats_perk0Var2
# participants_1_stats_perk0Var3
# participants_1_stats_perk1
# participants_1_stats_perk1Var1
# participants_1_stats_perk1Var2
# participants_1_stats_perk1Var3
# participants_1_stats_perk2
# participants_1_stats_perk2Var1
# participants_1_stats_perk2Var2
# participants_1_stats_perk2Var3
# participants_1_stats_perk3
# participants_1_stats_perk3Var1
# participants_1_stats_perk3Var2
# participants_1_stats_perk3Var3
# participants_1_stats_perk4
# participants_1_stats_perk4Var1
# participants_1_stats_perk4Var2
# participants_1_stats_perk4Var3
# participants_1_stats_perk5
# participants_1_stats_perk5Var1
# participants_1_stats_perk5Var2
# participants_1_stats_perk5Var3
# participants_1_stats_perkPrimaryStyle
# participants_1_stats_perkSubStyle
# participants_1_stats_statPerk0
# participants_1_stats_statPerk1
# participants_1_stats_statPerk2
# participants_1_timeline_creepsPerMinDeltas_10-20
# participants_1_timeline_creepsPerMinDeltas_0-10
# participants_1_timeline_xpPerMinDeltas_10-20
# participants_1_timeline_xpPerMinDeltas_0-10
# participants_1_timeline_goldPerMinDeltas_10-20
# participants_1_timeline_goldPerMinDeltas_0-10
# participants_1_timeline_damageTakenPerMinDeltas_10-20
# participants_1_timeline_damageTakenPerMinDeltas_0-10
# participants_1_timeline_role
# participants_1_timeline_lane
# participants_2_championId
# participants_2_spell1Id
# participants_2_spell2Id
# participants_2_stats_win
# participants_2_stats_item0
# participants_2_stats_item1
# participants_2_stats_item2
# participants_2_stats_item3
# participants_2_stats_item4
# participants_2_stats_item5
# participants_2_stats_item6
# participants_2_stats_kills
# participants_2_stats_deaths
# participants_2_stats_assists
# participants_2_stats_largestKillingSpree
# participants_2_stats_largestMultiKill
# participants_2_stats_killingSprees
# participants_2_stats_longestTimeSpentLiving
# participants_2_stats_doubleKills
# participants_2_stats_tripleKills
# participants_2_stats_quadraKills
# participants_2_stats_pentaKills
# participants_2_stats_unrealKills
# participants_2_stats_totalDamageDealt
# participants_2_stats_magicDamageDealt
# participants_2_stats_physicalDamageDealt
# participants_2_stats_trueDamageDealt
# participants_2_stats_largestCriticalStrike
# participants_2_stats_totalDamageDealtToChampions
# participants_2_stats_magicDamageDealtToChampions
# participants_2_stats_physicalDamageDealtToChampions
# participants_2_stats_trueDamageDealtToChampions
# participants_2_stats_totalHeal
# participants_2_stats_totalUnitsHealed
# participants_2_stats_damageSelfMitigated
# participants_2_stats_damageDealtToObjectives
# participants_2_stats_damageDealtToTurrets
# participants_2_stats_visionScore
# participants_2_stats_timeCCingOthers
# participants_2_stats_totalDamageTaken
# participants_2_stats_magicalDamageTaken
# participants_2_stats_physicalDamageTaken
# participants_2_stats_trueDamageTaken
# participants_2_stats_goldEarned
# participants_2_stats_goldSpent
# participants_2_stats_turretKills
# participants_2_stats_inhibitorKills
# participants_2_stats_totalMinionsKilled
# participants_2_stats_neutralMinionsKilled
# participants_2_stats_totalTimeCrowdControlDealt
# participants_2_stats_champLevel
# participants_2_stats_visionWardsBoughtInGame
# participants_2_stats_firstBloodKill
# participants_2_stats_firstBloodAssist
# participants_2_stats_firstTowerKill
# participants_2_stats_firstTowerAssist
# participants_2_stats_firstInhibitorKill
# participants_2_stats_firstInhibitorAssist
# participants_2_stats_playerScore6
# participants_2_stats_playerScore7
# participants_2_stats_perk0
# participants_2_stats_perk0Var1
# participants_2_stats_perk0Var2
# participants_2_stats_perk0Var3
# participants_2_stats_perk1
# participants_2_stats_perk1Var1
# participants_2_stats_perk1Var2
# participants_2_stats_perk1Var3
# participants_2_stats_perk2
# participants_2_stats_perk2Var1
# participants_2_stats_perk2Var2
# participants_2_stats_perk2Var3
# participants_2_stats_perk3
# participants_2_stats_perk3Var1
# participants_2_stats_perk3Var2
# participants_2_stats_perk3Var3
# participants_2_stats_perk4
# participants_2_stats_perk4Var1
# participants_2_stats_perk4Var2
# participants_2_stats_perk4Var3
# participants_2_stats_perk5
# participants_2_stats_perk5Var1
# participants_2_stats_perk5Var2
# participants_2_stats_perk5Var3
# participants_2_stats_perkPrimaryStyle
# participants_2_stats_perkSubStyle
# participants_2_stats_statPerk0
# participants_2_stats_statPerk1
# participants_2_stats_statPerk2
# participants_2_timeline_creepsPerMinDeltas_10-20
# participants_2_timeline_creepsPerMinDeltas_0-10
# participants_2_timeline_xpPerMinDeltas_10-20
# participants_2_timeline_xpPerMinDeltas_0-10
# participants_2_timeline_goldPerMinDeltas_10-20
# participants_2_timeline_goldPerMinDeltas_0-10
# participants_2_timeline_damageTakenPerMinDeltas_10-20
# participants_2_timeline_damageTakenPerMinDeltas_0-10
# participants_2_timeline_role
# participants_2_timeline_lane
# participants_3_championId
# participants_3_spell1Id
# participants_3_spell2Id
# participants_3_stats_win
# participants_3_stats_item0
# participants_3_stats_item1
# participants_3_stats_item2
# participants_3_stats_item3
# participants_3_stats_item4
# participants_3_stats_item5
# participants_3_stats_item6
# participants_3_stats_kills
# participants_3_stats_deaths
# participants_3_stats_assists
# participants_3_stats_largestKillingSpree
# participants_3_stats_largestMultiKill
# participants_3_stats_killingSprees
# participants_3_stats_longestTimeSpentLiving
# participants_3_stats_doubleKills
# participants_3_stats_tripleKills
# participants_3_stats_quadraKills
# participants_3_stats_pentaKills
# participants_3_stats_unrealKills
# participants_3_stats_totalDamageDealt
# participants_3_stats_magicDamageDealt
# participants_3_stats_physicalDamageDealt
# participants_3_stats_trueDamageDealt
# participants_3_stats_largestCriticalStrike
# participants_3_stats_totalDamageDealtToChampions
# participants_3_stats_magicDamageDealtToChampions
# participants_3_stats_physicalDamageDealtToChampions
# participants_3_stats_trueDamageDealtToChampions
# participants_3_stats_totalHeal
# participants_3_stats_totalUnitsHealed
# participants_3_stats_damageSelfMitigated
# participants_3_stats_damageDealtToObjectives
# participants_3_stats_damageDealtToTurrets
# participants_3_stats_visionScore
# participants_3_stats_timeCCingOthers
# participants_3_stats_totalDamageTaken
# participants_3_stats_magicalDamageTaken
# participants_3_stats_physicalDamageTaken
# participants_3_stats_trueDamageTaken
# participants_3_stats_goldEarned
# participants_3_stats_goldSpent
# participants_3_stats_turretKills
# participants_3_stats_inhibitorKills
# participants_3_stats_totalMinionsKilled
# participants_3_stats_neutralMinionsKilled
# participants_3_stats_totalTimeCrowdControlDealt
# participants_3_stats_champLevel
# participants_3_stats_visionWardsBoughtInGame
# participants_3_stats_firstBloodKill
# participants_3_stats_firstBloodAssist
# participants_3_stats_firstTowerKill
# participants_3_stats_firstTowerAssist
# participants_3_stats_firstInhibitorKill
# participants_3_stats_firstInhibitorAssist
# participants_3_stats_playerScore6
# participants_3_stats_playerScore7
# participants_3_stats_perk0
# participants_3_stats_perk0Var1
# participants_3_stats_perk0Var2
# participants_3_stats_perk0Var3
# participants_3_stats_perk1
# participants_3_stats_perk1Var1
# participants_3_stats_perk1Var2
# participants_3_stats_perk1Var3
# participants_3_stats_perk2
# participants_3_stats_perk2Var1
# participants_3_stats_perk2Var2
# participants_3_stats_perk2Var3
# participants_3_stats_perk3
# participants_3_stats_perk3Var1
# participants_3_stats_perk3Var2
# participants_3_stats_perk3Var3
# participants_3_stats_perk4
# participants_3_stats_perk4Var1
# participants_3_stats_perk4Var2
# participants_3_stats_perk4Var3
# participants_3_stats_perk5
# participants_3_stats_perk5Var1
# participants_3_stats_perk5Var2
# participants_3_stats_perk5Var3
# participants_3_stats_perkPrimaryStyle
# participants_3_stats_perkSubStyle
# participants_3_stats_statPerk0
# participants_3_stats_statPerk1
# participants_3_stats_statPerk2
# participants_3_timeline_creepsPerMinDeltas_10-20
# participants_3_timeline_creepsPerMinDeltas_0-10
# participants_3_timeline_xpPerMinDeltas_10-20
# participants_3_timeline_xpPerMinDeltas_0-10
# participants_3_timeline_goldPerMinDeltas_10-20
# participants_3_timeline_goldPerMinDeltas_0-10
# participants_3_timeline_damageTakenPerMinDeltas_10-20
# participants_3_timeline_damageTakenPerMinDeltas_0-10
# participants_3_timeline_role
# participants_3_timeline_lane
# participants_4_championId
# participants_4_spell1Id
# participants_4_spell2Id
# participants_4_stats_win
# participants_4_stats_item0
# participants_4_stats_item1
# participants_4_stats_item2
# participants_4_stats_item3
# participants_4_stats_item4
# participants_4_stats_item5
# participants_4_stats_item6
# participants_4_stats_kills
# participants_4_stats_deaths
# participants_4_stats_assists
# participants_4_stats_largestKillingSpree
# participants_4_stats_largestMultiKill
# participants_4_stats_killingSprees
# participants_4_stats_longestTimeSpentLiving
# participants_4_stats_doubleKills
# participants_4_stats_tripleKills
# participants_4_stats_quadraKills
# participants_4_stats_pentaKills
# participants_4_stats_unrealKills
# participants_4_stats_totalDamageDealt
# participants_4_stats_magicDamageDealt
# participants_4_stats_physicalDamageDealt
# participants_4_stats_trueDamageDealt
# participants_4_stats_largestCriticalStrike
# participants_4_stats_totalDamageDealtToChampions
# participants_4_stats_magicDamageDealtToChampions
# participants_4_stats_physicalDamageDealtToChampions
# participants_4_stats_trueDamageDealtToChampions
# participants_4_stats_totalHeal
# participants_4_stats_totalUnitsHealed
# participants_4_stats_damageSelfMitigated
# participants_4_stats_damageDealtToObjectives
# participants_4_stats_damageDealtToTurrets
# participants_4_stats_visionScore
# participants_4_stats_timeCCingOthers
# participants_4_stats_totalDamageTaken
# participants_4_stats_magicalDamageTaken
# participants_4_stats_physicalDamageTaken
# participants_4_stats_trueDamageTaken
# participants_4_stats_goldEarned
# participants_4_stats_goldSpent
# participants_4_stats_turretKills
# participants_4_stats_inhibitorKills
# participants_4_stats_totalMinionsKilled
# participants_4_stats_neutralMinionsKilled
# participants_4_stats_totalTimeCrowdControlDealt
# participants_4_stats_champLevel
# participants_4_stats_visionWardsBoughtInGame
# participants_4_stats_firstBloodKill
# participants_4_stats_firstBloodAssist
# participants_4_stats_firstTowerKill
# participants_4_stats_firstTowerAssist
# participants_4_stats_firstInhibitorKill
# participants_4_stats_firstInhibitorAssist
# participants_4_stats_playerScore5
# participants_4_stats_playerScore6
# participants_4_stats_playerScore7
# participants_4_stats_playerScore8
# participants_4_stats_perk0
# participants_4_stats_perk0Var1
# participants_4_stats_perk0Var2
# participants_4_stats_perk0Var3
# participants_4_stats_perk1
# participants_4_stats_perk1Var1
# participants_4_stats_perk1Var2
# participants_4_stats_perk1Var3
# participants_4_stats_perk2
# participants_4_stats_perk2Var1
# participants_4_stats_perk2Var2
# participants_4_stats_perk2Var3
# participants_4_stats_perk3
# participants_4_stats_perk3Var1
# participants_4_stats_perk3Var2
# participants_4_stats_perk3Var3
# participants_4_stats_perk4
# participants_4_stats_perk4Var1
# participants_4_stats_perk4Var2
# participants_4_stats_perk4Var3
# participants_4_stats_perk5
# participants_4_stats_perk5Var1
# participants_4_stats_perk5Var2
# participants_4_stats_perk5Var3
# participants_4_stats_perkPrimaryStyle
# participants_4_stats_perkSubStyle
# participants_4_stats_statPerk0
# participants_4_stats_statPerk1
# participants_4_stats_statPerk2
# participants_4_timeline_creepsPerMinDeltas_10-20
# participants_4_timeline_creepsPerMinDeltas_0-10
# participants_4_timeline_xpPerMinDeltas_10-20
# participants_4_timeline_xpPerMinDeltas_0-10
# participants_4_timeline_goldPerMinDeltas_10-20
# participants_4_timeline_goldPerMinDeltas_0-10
# participants_4_timeline_damageTakenPerMinDeltas_10-20
# participants_4_timeline_damageTakenPerMinDeltas_0-10
# participants_4_timeline_role
# participants_4_timeline_lane
# participants_5_championId
# participants_5_spell1Id
# participants_5_spell2Id
# participants_5_stats_win
# participants_5_stats_item0
# participants_5_stats_item1
# participants_5_stats_item2
# participants_5_stats_item3
# participants_5_stats_item4
# participants_5_stats_item5
# participants_5_stats_item6
# participants_5_stats_kills
# participants_5_stats_deaths
# participants_5_stats_assists
# participants_5_stats_largestKillingSpree
# participants_5_stats_largestMultiKill
# participants_5_stats_killingSprees
# participants_5_stats_longestTimeSpentLiving
# participants_5_stats_doubleKills
# participants_5_stats_tripleKills
# participants_5_stats_quadraKills
# participants_5_stats_pentaKills
# participants_5_stats_totalDamageDealt
# participants_5_stats_magicDamageDealt
# participants_5_stats_physicalDamageDealt
# participants_5_stats_trueDamageDealt
# participants_5_stats_largestCriticalStrike
# participants_5_stats_totalDamageDealtToChampions
# participants_5_stats_magicDamageDealtToChampions
# participants_5_stats_physicalDamageDealtToChampions
# participants_5_stats_trueDamageDealtToChampions
# participants_5_stats_totalHeal
# participants_5_stats_totalUnitsHealed
# participants_5_stats_damageSelfMitigated
# participants_5_stats_damageDealtToObjectives
# participants_5_stats_damageDealtToTurrets
# participants_5_stats_visionScore
# participants_5_stats_timeCCingOthers
# participants_5_stats_totalDamageTaken
# participants_5_stats_magicalDamageTaken
# participants_5_stats_physicalDamageTaken
# participants_5_stats_trueDamageTaken
# participants_5_stats_goldEarned
# participants_5_stats_goldSpent
# participants_5_stats_turretKills
# participants_5_stats_inhibitorKills
# participants_5_stats_totalMinionsKilled
# participants_5_stats_neutralMinionsKilled
# participants_5_stats_totalTimeCrowdControlDealt
# participants_5_stats_champLevel
# participants_5_stats_visionWardsBoughtInGame
# participants_5_stats_firstBloodKill
# participants_5_stats_firstBloodAssist
# participants_5_stats_firstTowerKill
# participants_5_stats_firstTowerAssist
# participants_5_stats_firstInhibitorKill
# participants_5_stats_firstInhibitorAssist
# participants_5_stats_playerScore4
# participants_5_stats_playerScore6
# participants_5_stats_playerScore7
# participants_5_stats_perk0
# participants_5_stats_perk0Var1
# participants_5_stats_perk0Var2
# participants_5_stats_perk0Var3
# participants_5_stats_perk1
# participants_5_stats_perk1Var1
# participants_5_stats_perk1Var2
# participants_5_stats_perk1Var3
# participants_5_stats_perk2
# participants_5_stats_perk2Var1
# participants_5_stats_perk2Var2
# participants_5_stats_perk2Var3
# participants_5_stats_perk3
# participants_5_stats_perk3Var1
# participants_5_stats_perk3Var2
# participants_5_stats_perk3Var3
# participants_5_stats_perk4
# participants_5_stats_perk4Var1
# participants_5_stats_perk4Var2
# participants_5_stats_perk4Var3
# participants_5_stats_perk5
# participants_5_stats_perk5Var1
# participants_5_stats_perk5Var2
# participants_5_stats_perk5Var3
# participants_5_stats_perkPrimaryStyle
# participants_5_stats_perkSubStyle
# participants_5_stats_statPerk0
# participants_5_stats_statPerk1
# participants_5_stats_statPerk2
# participants_5_timeline_creepsPerMinDeltas_10-20
# participants_5_timeline_creepsPerMinDeltas_0-10
# participants_5_timeline_xpPerMinDeltas_10-20
# participants_5_timeline_xpPerMinDeltas_0-10
# participants_5_timeline_goldPerMinDeltas_10-20
# participants_5_timeline_goldPerMinDeltas_0-10
# participants_5_timeline_damageTakenPerMinDeltas_10-20
# participants_5_timeline_damageTakenPerMinDeltas_0-10
# participants_5_timeline_role
# participants_5_timeline_lane
# participants_6_championId
# participants_6_spell1Id
# participants_6_spell2Id
# participants_6_stats_win
# participants_6_stats_item0
# participants_6_stats_item1
# participants_6_stats_item2
# participants_6_stats_item3
# participants_6_stats_item4
# participants_6_stats_item5
# participants_6_stats_item6
# participants_6_stats_kills
# participants_6_stats_deaths
# participants_6_stats_assists
# participants_6_stats_largestKillingSpree
# participants_6_stats_largestMultiKill
# participants_6_stats_killingSprees
# participants_6_stats_longestTimeSpentLiving
# participants_6_stats_doubleKills
# participants_6_stats_tripleKills
# participants_6_stats_quadraKills
# participants_6_stats_pentaKills
# participants_6_stats_totalDamageDealt
# participants_6_stats_magicDamageDealt
# participants_6_stats_physicalDamageDealt
# participants_6_stats_trueDamageDealt
# participants_6_stats_largestCriticalStrike
# participants_6_stats_totalDamageDealtToChampions
# participants_6_stats_magicDamageDealtToChampions
# participants_6_stats_physicalDamageDealtToChampions
# participants_6_stats_trueDamageDealtToChampions
# participants_6_stats_totalHeal
# participants_6_stats_totalUnitsHealed
# participants_6_stats_damageSelfMitigated
# participants_6_stats_damageDealtToObjectives
# participants_6_stats_damageDealtToTurrets
# participants_6_stats_visionScore
# participants_6_stats_timeCCingOthers
# participants_6_stats_totalDamageTaken
# participants_6_stats_magicalDamageTaken
# participants_6_stats_physicalDamageTaken
# participants_6_stats_trueDamageTaken
# participants_6_stats_goldEarned
# participants_6_stats_goldSpent
# participants_6_stats_turretKills
# participants_6_stats_inhibitorKills
# participants_6_stats_totalMinionsKilled
# participants_6_stats_neutralMinionsKilled
# participants_6_stats_totalTimeCrowdControlDealt
# participants_6_stats_champLevel
# participants_6_stats_visionWardsBoughtInGame
# participants_6_stats_firstBloodKill
# participants_6_stats_firstBloodAssist
# participants_6_stats_firstTowerKill
# participants_6_stats_firstTowerAssist
# participants_6_stats_firstInhibitorKill
# participants_6_stats_firstInhibitorAssist
# participants_6_stats_playerScore6
# participants_6_stats_playerScore7
# participants_6_stats_perk0
# participants_6_stats_perk0Var1
# participants_6_stats_perk0Var2
# participants_6_stats_perk0Var3
# participants_6_stats_perk1
# participants_6_stats_perk1Var1
# participants_6_stats_perk1Var2
# participants_6_stats_perk1Var3
# participants_6_stats_perk2
# participants_6_stats_perk2Var1
# participants_6_stats_perk2Var2
# participants_6_stats_perk2Var3
# participants_6_stats_perk3
# participants_6_stats_perk3Var1
# participants_6_stats_perk3Var2
# participants_6_stats_perk3Var3
# participants_6_stats_perk4
# participants_6_stats_perk4Var1
# participants_6_stats_perk4Var2
# participants_6_stats_perk4Var3
# participants_6_stats_perk5
# participants_6_stats_perk5Var1
# participants_6_stats_perk5Var2
# participants_6_stats_perk5Var3
# participants_6_stats_perkPrimaryStyle
# participants_6_stats_perkSubStyle
# participants_6_stats_statPerk0
# participants_6_stats_statPerk1
# participants_6_stats_statPerk2
# participants_6_timeline_creepsPerMinDeltas_10-20
# participants_6_timeline_creepsPerMinDeltas_0-10
# participants_6_timeline_xpPerMinDeltas_10-20
# participants_6_timeline_xpPerMinDeltas_0-10
# participants_6_timeline_goldPerMinDeltas_10-20
# participants_6_timeline_goldPerMinDeltas_0-10
# participants_6_timeline_damageTakenPerMinDeltas_10-20
# participants_6_timeline_damageTakenPerMinDeltas_0-10
# participants_6_timeline_role
# participants_6_timeline_lane
# participants_7_championId
# participants_7_spell1Id
# participants_7_spell2Id
# participants_7_stats_win
# participants_7_stats_item0
# participants_7_stats_item1
# participants_7_stats_item2
# participants_7_stats_item3
# participants_7_stats_item4
# participants_7_stats_item5
# participants_7_stats_item6
# participants_7_stats_kills
# participants_7_stats_deaths
# participants_7_stats_assists
# participants_7_stats_largestKillingSpree
# participants_7_stats_largestMultiKill
# participants_7_stats_killingSprees
# participants_7_stats_longestTimeSpentLiving
# participants_7_stats_doubleKills
# participants_7_stats_tripleKills
# participants_7_stats_quadraKills
# participants_7_stats_pentaKills
# participants_7_stats_totalDamageDealt
# participants_7_stats_magicDamageDealt
# participants_7_stats_physicalDamageDealt
# participants_7_stats_trueDamageDealt
# participants_7_stats_largestCriticalStrike
# participants_7_stats_totalDamageDealtToChampions
# participants_7_stats_magicDamageDealtToChampions
# participants_7_stats_physicalDamageDealtToChampions
# participants_7_stats_trueDamageDealtToChampions
# participants_7_stats_totalHeal
# participants_7_stats_totalUnitsHealed
# participants_7_stats_damageSelfMitigated
# participants_7_stats_damageDealtToObjectives
# participants_7_stats_damageDealtToTurrets
# participants_7_stats_visionScore
# participants_7_stats_timeCCingOthers
# participants_7_stats_totalDamageTaken
# participants_7_stats_magicalDamageTaken
# participants_7_stats_physicalDamageTaken
# participants_7_stats_trueDamageTaken
# participants_7_stats_goldEarned
# participants_7_stats_goldSpent
# participants_7_stats_turretKills
# participants_7_stats_inhibitorKills
# participants_7_stats_totalMinionsKilled
# participants_7_stats_neutralMinionsKilled
# participants_7_stats_totalTimeCrowdControlDealt
# participants_7_stats_champLevel
# participants_7_stats_visionWardsBoughtInGame
# participants_7_stats_firstBloodKill
# participants_7_stats_firstBloodAssist
# participants_7_stats_firstTowerKill
# participants_7_stats_firstTowerAssist
# participants_7_stats_firstInhibitorKill
# participants_7_stats_firstInhibitorAssist
# participants_7_stats_playerScore4
# participants_7_stats_playerScore5
# participants_7_stats_playerScore6
# participants_7_stats_playerScore7
# participants_7_stats_perk0
# participants_7_stats_perk0Var1
# participants_7_stats_perk0Var2
# participants_7_stats_perk0Var3
# participants_7_stats_perk1
# participants_7_stats_perk1Var1
# participants_7_stats_perk1Var2
# participants_7_stats_perk1Var3
# participants_7_stats_perk2
# participants_7_stats_perk2Var1
# participants_7_stats_perk2Var2
# participants_7_stats_perk2Var3
# participants_7_stats_perk3
# participants_7_stats_perk3Var1
# participants_7_stats_perk3Var2
# participants_7_stats_perk3Var3
# participants_7_stats_perk4
# participants_7_stats_perk4Var1
# participants_7_stats_perk4Var2
# participants_7_stats_perk4Var3
# participants_7_stats_perk5
# participants_7_stats_perk5Var1
# participants_7_stats_perk5Var2
# participants_7_stats_perk5Var3
# participants_7_stats_perkPrimaryStyle
# participants_7_stats_perkSubStyle
# participants_7_stats_statPerk0
# participants_7_stats_statPerk1
# participants_7_stats_statPerk2
# participants_7_timeline_creepsPerMinDeltas_10-20
# participants_7_timeline_creepsPerMinDeltas_0-10
# participants_7_timeline_xpPerMinDeltas_10-20
# participants_7_timeline_xpPerMinDeltas_0-10
# participants_7_timeline_goldPerMinDeltas_10-20
# participants_7_timeline_goldPerMinDeltas_0-10
# participants_7_timeline_damageTakenPerMinDeltas_10-20
# participants_7_timeline_damageTakenPerMinDeltas_0-10
# participants_7_timeline_role
# participants_7_timeline_lane
# participants_8_championId
# participants_8_spell1Id
# participants_8_spell2Id
# participants_8_stats_win
# participants_8_stats_item0
# participants_8_stats_item1
# participants_8_stats_item2
# participants_8_stats_item3
# participants_8_stats_item4
# participants_8_stats_item5
# participants_8_stats_item6
# participants_8_stats_kills
# participants_8_stats_deaths
# participants_8_stats_assists
# participants_8_stats_largestKillingSpree
# participants_8_stats_largestMultiKill
# participants_8_stats_killingSprees
# participants_8_stats_longestTimeSpentLiving
# participants_8_stats_doubleKills
# participants_8_stats_tripleKills
# participants_8_stats_quadraKills
# participants_8_stats_pentaKills
# participants_8_stats_totalDamageDealt
# participants_8_stats_magicDamageDealt
# participants_8_stats_physicalDamageDealt
# participants_8_stats_trueDamageDealt
# participants_8_stats_largestCriticalStrike
# participants_8_stats_totalDamageDealtToChampions
# participants_8_stats_magicDamageDealtToChampions
# participants_8_stats_physicalDamageDealtToChampions
# participants_8_stats_trueDamageDealtToChampions
# participants_8_stats_totalHeal
# participants_8_stats_totalUnitsHealed
# participants_8_stats_damageSelfMitigated
# participants_8_stats_damageDealtToObjectives
# participants_8_stats_damageDealtToTurrets
# participants_8_stats_visionScore
# participants_8_stats_timeCCingOthers
# participants_8_stats_totalDamageTaken
# participants_8_stats_magicalDamageTaken
# participants_8_stats_physicalDamageTaken
# participants_8_stats_trueDamageTaken
# participants_8_stats_goldEarned
# participants_8_stats_goldSpent
# participants_8_stats_turretKills
# participants_8_stats_inhibitorKills
# participants_8_stats_totalMinionsKilled
# participants_8_stats_neutralMinionsKilled
# participants_8_stats_totalTimeCrowdControlDealt
# participants_8_stats_champLevel
# participants_8_stats_visionWardsBoughtInGame
# participants_8_stats_firstBloodKill
# participants_8_stats_firstBloodAssist
# participants_8_stats_firstTowerKill
# participants_8_stats_firstTowerAssist
# participants_8_stats_firstInhibitorKill
# participants_8_stats_firstInhibitorAssist
# participants_8_stats_playerScore1
# participants_8_stats_playerScore6
# participants_8_stats_playerScore7
# participants_8_stats_playerScore8
# participants_8_stats_perk0
# participants_8_stats_perk0Var1
# participants_8_stats_perk0Var2
# participants_8_stats_perk0Var3
# participants_8_stats_perk1
# participants_8_stats_perk1Var1
# participants_8_stats_perk1Var2
# participants_8_stats_perk1Var3
# participants_8_stats_perk2
# participants_8_stats_perk2Var1
# participants_8_stats_perk2Var2
# participants_8_stats_perk2Var3
# participants_8_stats_perk3
# participants_8_stats_perk3Var1
# participants_8_stats_perk3Var2
# participants_8_stats_perk3Var3
# participants_8_stats_perk4
# participants_8_stats_perk4Var1
# participants_8_stats_perk4Var2
# participants_8_stats_perk4Var3
# participants_8_stats_perk5
# participants_8_stats_perk5Var1
# participants_8_stats_perk5Var2
# participants_8_stats_perk5Var3
# participants_8_stats_perkPrimaryStyle
# participants_8_stats_perkSubStyle
# participants_8_stats_statPerk0
# participants_8_stats_statPerk1
# participants_8_stats_statPerk2
# participants_8_timeline_creepsPerMinDeltas_10-20
# participants_8_timeline_creepsPerMinDeltas_0-10
# participants_8_timeline_xpPerMinDeltas_10-20
# participants_8_timeline_xpPerMinDeltas_0-10
# participants_8_timeline_goldPerMinDeltas_10-20
# participants_8_timeline_goldPerMinDeltas_0-10
# participants_8_timeline_damageTakenPerMinDeltas_10-20
# participants_8_timeline_damageTakenPerMinDeltas_0-10
# participants_8_timeline_role
# participants_8_timeline_lane
# participants_9_championId
# participants_9_spell1Id
# participants_9_spell2Id
# participants_9_stats_win
# participants_9_stats_item0
# participants_9_stats_item1
# participants_9_stats_item2
# participants_9_stats_item3
# participants_9_stats_item4
# participants_9_stats_item5
# participants_9_stats_item6
# participants_9_stats_kills
# participants_9_stats_deaths
# participants_9_stats_assists
# participants_9_stats_largestKillingSpree
# participants_9_stats_largestMultiKill
# participants_9_stats_killingSprees
# participants_9_stats_longestTimeSpentLiving
# participants_9_stats_doubleKills
# participants_9_stats_tripleKills
# participants_9_stats_quadraKills
# participants_9_stats_pentaKills
# participants_9_stats_totalDamageDealt
# participants_9_stats_magicDamageDealt
# participants_9_stats_physicalDamageDealt
# participants_9_stats_trueDamageDealt
# participants_9_stats_largestCriticalStrike
# participants_9_stats_totalDamageDealtToChampions
# participants_9_stats_magicDamageDealtToChampions
# participants_9_stats_physicalDamageDealtToChampions
# participants_9_stats_trueDamageDealtToChampions
# participants_9_stats_totalHeal
# participants_9_stats_totalUnitsHealed
# participants_9_stats_damageSelfMitigated
# participants_9_stats_damageDealtToObjectives
# participants_9_stats_damageDealtToTurrets
# participants_9_stats_visionScore
# participants_9_stats_timeCCingOthers
# participants_9_stats_totalDamageTaken
# participants_9_stats_magicalDamageTaken
# participants_9_stats_physicalDamageTaken
# participants_9_stats_trueDamageTaken
# participants_9_stats_goldEarned
# participants_9_stats_goldSpent
# participants_9_stats_turretKills
# participants_9_stats_inhibitorKills
# participants_9_stats_totalMinionsKilled
# participants_9_stats_neutralMinionsKilled
# participants_9_stats_totalTimeCrowdControlDealt
# participants_9_stats_champLevel
# participants_9_stats_visionWardsBoughtInGame
# participants_9_stats_firstBloodKill
# participants_9_stats_firstBloodAssist
# participants_9_stats_firstTowerKill
# participants_9_stats_firstTowerAssist
# participants_9_stats_firstInhibitorKill
# participants_9_stats_firstInhibitorAssist
# participants_9_stats_playerScore4
# participants_9_stats_playerScore5
# participants_9_stats_playerScore6
# participants_9_stats_playerScore7
# participants_9_stats_perk0
# participants_9_stats_perk0Var1
# participants_9_stats_perk0Var2
# participants_9_stats_perk0Var3
# participants_9_stats_perk1
# participants_9_stats_perk1Var1
# participants_9_stats_perk1Var2
# participants_9_stats_perk1Var3
# participants_9_stats_perk2
# participants_9_stats_perk2Var1
# participants_9_stats_perk2Var2
# participants_9_stats_perk2Var3
# participants_9_stats_perk3
# participants_9_stats_perk3Var1
# participants_9_stats_perk3Var2
# participants_9_stats_perk3Var3
# participants_9_stats_perk4
# participants_9_stats_perk4Var1
# participants_9_stats_perk4Var2
# participants_9_stats_perk4Var3
# participants_9_stats_perk5
# participants_9_stats_perk5Var1
# participants_9_stats_perk5Var2
# participants_9_stats_perk5Var3
# participants_9_stats_perkPrimaryStyle
# participants_9_stats_perkSubStyle
# participants_9_stats_statPerk0
# participants_9_stats_statPerk1
# participants_9_stats_statPerk2
# participants_9_timeline_creepsPerMinDeltas_10-20
# participants_9_timeline_creepsPerMinDeltas_0-10
# participants_9_timeline_xpPerMinDeltas_10-20
# participants_9_timeline_xpPerMinDeltas_0-10
# participants_9_timeline_goldPerMinDeltas_10-20
# participants_9_timeline_goldPerMinDeltas_0-10
# participants_9_timeline_damageTakenPerMinDeltas_10-20
# participants_9_timeline_damageTakenPerMinDeltas_0-10
# participants_9_timeline_role
# participants_9_timeline_lane
# participantIdentities_0_player_platformId
# participantIdentities_0_player_accountId
# participantIdentities_0_player_summonerName
# participantIdentities_0_player_summonerId
# participantIdentities_0_player_currentAccountId
# participantIdentities_0_player_matchHistoryUri
# participantIdentities_0_player_profileIcon
# participantIdentities_1_player_platformId
# participantIdentities_1_player_accountId
# participantIdentities_1_player_summonerName
# participantIdentities_1_player_summonerId
# participantIdentities_1_player_currentAccountId
# participantIdentities_1_player_matchHistoryUri
# participantIdentities_1_player_profileIcon
# participantIdentities_2_player_platformId
# participantIdentities_2_player_accountId
# participantIdentities_2_player_summonerName
# participantIdentities_2_player_summonerId
# participantIdentities_2_player_currentAccountId
# participantIdentities_2_player_matchHistoryUri
# participantIdentities_2_player_profileIcon
# participantIdentities_3_player_platformId
# participantIdentities_3_player_accountId
# participantIdentities_3_player_summonerName
# participantIdentities_3_player_summonerId
# participantIdentities_3_player_currentAccountId
# participantIdentities_3_player_matchHistoryUri
# participantIdentities_3_player_profileIcon
# participantIdentities_4_player_platformId
# participantIdentities_4_player_accountId
# participantIdentities_4_player_summonerName
# participantIdentities_4_player_summonerId
# participantIdentities_4_player_currentAccountId
# participantIdentities_4_player_matchHistoryUri
# participantIdentities_4_player_profileIcon
# participantIdentities_5_player_platformId
# participantIdentities_5_player_accountId
# participantIdentities_5_player_summonerName
# participantIdentities_5_player_summonerId
# participantIdentities_5_player_currentAccountId
# participantIdentities_5_player_matchHistoryUri
# participantIdentities_5_player_profileIcon
# participantIdentities_6_player_platformId
# participantIdentities_6_player_accountId
# participantIdentities_6_player_summonerName
# participantIdentities_6_player_summonerId
# participantIdentities_6_player_currentAccountId
# participantIdentities_6_player_matchHistoryUri
# participantIdentities_6_player_profileIcon
# participantIdentities_7_player_platformId
# participantIdentities_7_player_accountId
# participantIdentities_7_player_summonerName
# participantIdentities_7_player_summonerId
# participantIdentities_7_player_currentAccountId
# participantIdentities_7_player_matchHistoryUri
# participantIdentities_7_player_profileIcon
# participantIdentities_8_player_platformId
# participantIdentities_8_player_accountId
# participantIdentities_8_player_summonerName
# participantIdentities_8_player_summonerId
# participantIdentities_8_player_currentAccountId
# participantIdentities_8_player_matchHistoryUri
# participantIdentities_8_player_profileIcon
# participantIdentities_9_player_platformId
# participantIdentities_9_player_accountId
# participantIdentities_9_player_summonerName
# participantIdentities_9_player_summonerId
# participantIdentities_9_player_currentAccountId
# participantIdentities_9_player_matchHistoryUri
# participantIdentities_9_player_profileIcon
# participants_0_timeline_csDiffPerMinDeltas_0-10
# participants_0_timeline_xpDiffPerMinDeltas_0-10
# participants_0_timeline_damageTakenDiffPerMinDeltas_0-10
# participants_1_timeline_csDiffPerMinDeltas_0-10
# participants_1_timeline_xpDiffPerMinDeltas_0-10
# participants_1_timeline_damageTakenDiffPerMinDeltas_0-10
# participants_2_timeline_csDiffPerMinDeltas_0-10
# participants_2_timeline_xpDiffPerMinDeltas_0-10
# participants_2_timeline_damageTakenDiffPerMinDeltas_0-10
# participants_3_timeline_csDiffPerMinDeltas_0-10
# participants_3_timeline_xpDiffPerMinDeltas_0-10
# participants_3_timeline_damageTakenDiffPerMinDeltas_0-10
# participants_4_timeline_csDiffPerMinDeltas_0-10
# participants_4_timeline_xpDiffPerMinDeltas_0-10
# participants_4_timeline_damageTakenDiffPerMinDeltas_0-10
# participants_5_timeline_csDiffPerMinDeltas_0-10
# participants_5_timeline_xpDiffPerMinDeltas_0-10
# participants_5_timeline_damageTakenDiffPerMinDeltas_0-10
# participants_6_timeline_csDiffPerMinDeltas_0-10
# participants_6_timeline_xpDiffPerMinDeltas_0-10
# participants_6_timeline_damageTakenDiffPerMinDeltas_0-10
# participants_7_timeline_csDiffPerMinDeltas_0-10
# participants_7_timeline_xpDiffPerMinDeltas_0-10
# participants_7_timeline_damageTakenDiffPerMinDeltas_0-10
# participants_8_timeline_csDiffPerMinDeltas_0-10
# participants_8_timeline_xpDiffPerMinDeltas_0-10
# participants_8_timeline_damageTakenDiffPerMinDeltas_0-10
# participants_9_timeline_csDiffPerMinDeltas_0-10
# participants_9_timeline_xpDiffPerMinDeltas_0-10
# participants_9_timeline_damageTakenDiffPerMinDeltas_0-10
# teams_0_bans_0_championId
# teams_0_bans_0_pickTurn
# teams_0_bans_1_championId
# teams_0_bans_1_pickTurn
# teams_0_bans_2_championId
# teams_0_bans_2_pickTurn
# teams_0_bans_3_championId
# teams_0_bans_3_pickTurn
# teams_0_bans_4_championId
# teams_0_bans_4_pickTurn
# teams_1_bans_0_championId
# teams_1_bans_0_pickTurn
# teams_1_bans_1_championId
# teams_1_bans_1_pickTurn
# teams_1_bans_2_championId
# teams_1_bans_2_pickTurn
# teams_1_bans_3_championId
# teams_1_bans_3_pickTurn
# teams_1_bans_4_championId
# teams_1_bans_4_pickTurn
# participants_0_stats_neutralMinionsKilledTeamJungle
# participants_0_stats_neutralMinionsKilledEnemyJungle
# participants_0_stats_wardsPlaced
# participants_0_stats_wardsKilled
# participants_1_stats_neutralMinionsKilledTeamJungle
# participants_1_stats_neutralMinionsKilledEnemyJungle
# participants_1_stats_wardsPlaced
# participants_1_stats_wardsKilled
# participants_2_stats_neutralMinionsKilledTeamJungle
# participants_2_stats_neutralMinionsKilledEnemyJungle
# participants_2_stats_wardsPlaced
# participants_2_stats_wardsKilled
# participants_3_stats_neutralMinionsKilledTeamJungle
# participants_3_stats_neutralMinionsKilledEnemyJungle
# participants_3_stats_wardsPlaced
# participants_3_stats_wardsKilled
# participants_4_stats_neutralMinionsKilledTeamJungle
# participants_4_stats_neutralMinionsKilledEnemyJungle
# participants_4_stats_wardsPlaced
# participants_4_stats_wardsKilled
# participants_5_stats_neutralMinionsKilledTeamJungle
# participants_5_stats_neutralMinionsKilledEnemyJungle
# participants_5_stats_wardsPlaced
# participants_5_stats_wardsKilled
# participants_6_stats_neutralMinionsKilledTeamJungle
# participants_6_stats_neutralMinionsKilledEnemyJungle
# participants_6_stats_wardsPlaced
# participants_6_stats_wardsKilled
# participants_7_stats_neutralMinionsKilledTeamJungle
# participants_7_stats_neutralMinionsKilledEnemyJungle
# participants_7_stats_wardsPlaced
# participants_7_stats_wardsKilled
# participants_8_stats_neutralMinionsKilledTeamJungle
# participants_8_stats_neutralMinionsKilledEnemyJungle
# participants_8_stats_wardsPlaced
# participants_8_stats_wardsKilled
# participants_9_stats_neutralMinionsKilledTeamJungle
# participants_9_stats_neutralMinionsKilledEnemyJungle
# participants_9_stats_wardsPlaced
# participants_9_stats_wardsKilled

# %%
### Participants 0 - 4 are on team 0
all(df["teams_0_win"] == df["participants_4_stats_win"])
# Out:
# True

# %%
champions = df[["gameId", "teams_0_win", 
                "participants_0_championId", "participants_1_championId", 
                "participants_2_championId", "participants_3_championId", 
                "participants_4_championId", "participants_5_championId", 
                "participants_6_championId", "participants_7_championId",
                "participants_8_championId", "participants_9_championId",
                "participants_0_stats_win", "participants_1_stats_win", 
                "participants_2_stats_win", "participants_3_stats_win",
                "participants_4_stats_win", "participants_5_stats_win",
                "participants_6_stats_win", "participants_7_stats_win",
                "participants_8_stats_win","participants_9_stats_win",
                "participants_0_timeline_lane", "participants_1_timeline_lane", 
                "participants_2_timeline_lane", "participants_3_timeline_lane", 
                "participants_4_timeline_lane", "participants_5_timeline_lane", 
                "participants_6_timeline_lane", "participants_7_timeline_lane",
                "participants_8_timeline_lane", "participants_9_timeline_lane",]].copy()

# %%
champions
# Out:
#            gameId  teams_0_win participants_0_championId  \
# 0      3425927177            1                      Fizz
# 1      3463315468            0                  Volibear
# 2      3490775054            0                      Kayn
# 3      3449782290            0                   Leblanc
# 4      3482451986            1                      Ryze
# ...           ...          ...                       ...
# 29468  3487563744            1                    Soraka
# 29469  3480158177            1                    Ezreal
# 29470  3326738405            1                   Kalista
# 29471  3479175144            1                    Ezreal
# 29472  3310223355            0                     Janna
#
#       participants_1_championId participants_2_championId  \
# 0                         Karma                    Lucian
# 1                        Ezreal                     Braum
# 2                      Katarina                     Senna
# 3                        Ezreal                   Kindred
# 4                      Aphelios                   Leblanc
# ...                         ...                       ...
# 29468                Cassiopeia                    Thresh
# 29469                     Fiora                     Galio
# 29470                   Shyvana                     Fiora
# 29471                     Karma                     Sylas
# 29472                     Poppy                     Sylas
#
#       participants_3_championId participants_4_championId  \
# 0                       Kindred                      Ornn
# 1                       Hecarim               TwistedFate
# 2                          Bard                     Jayce
# 3                         Karma                    Maokai
# 4                      JarvanIV                     Galio
# ...                         ...                       ...
# 29468                  MasterYi                       Zed
# 29469                       Lux                    Graves
# 29470                  Pantheon                Cassiopeia
# 29471                   Camille              Fiddlesticks
# 29472                  Aphelios                    LeeSin
#
#       participants_5_championId participants_6_championId  \
# 0                          Pyke                   Alistar
# 1                      Renekton                   Kalista
# 2                        Irelia                Blitzcrank
# 3                        RekSai                      Ryze
# 4                          Ekko                    Qiyana
# ...                         ...                       ...
# 29468                  Pantheon                    Khazix
# 29469                       Zac                   Camille
# 29470                     Elise               MissFortune
# 29471              Heimerdinger                  Renekton
# 29472                      Ornn                   Kalista
#
#       participants_7_championId  ... participants_0_timeline_lane  \
# 0                     Gangplank  ...                       MIDDLE
# 1                         Taric  ...                          TOP
# 2                        Ezreal  ...                       JUNGLE
# 3                         Yasuo  ...                       MIDDLE
# 4                        Irelia  ...                          TOP
# ...                         ...  ...                          ...
# 29468                      Lulu  ...                       BOTTOM
# 29469                   Taliyah  ...                         NONE
# 29470                    Darius  ...                       MIDDLE
# 29471                     Varus  ...                       BOTTOM
# 29472                     Taric  ...                         NONE
#
#       participants_1_timeline_lane  participants_2_timeline_lane  \
# 0                           BOTTOM                        MIDDLE
# 1                           MIDDLE                           TOP
# 2                           MIDDLE                        BOTTOM
# 3                           MIDDLE                        JUNGLE
# 4                           MIDDLE                        MIDDLE
# ...                            ...                           ...
# 29468                          TOP                        BOTTOM
# 29469                         NONE                          NONE
# 29470                       JUNGLE                           TOP
# 29471                       BOTTOM                        MIDDLE
# 29472                         NONE                          NONE
#
#        participants_3_timeline_lane  participants_4_timeline_lane  \
# 0                            JUNGLE                           TOP
# 1                            JUNGLE                           TOP
# 2                            BOTTOM                           TOP
# 3                            MIDDLE                           TOP
# 4                            JUNGLE                        BOTTOM
# ...                             ...                           ...
# 29468                        JUNGLE                           TOP
# 29469                          NONE                          NONE
# 29470                        BOTTOM                        BOTTOM
# 29471                        JUNGLE                        JUNGLE
# 29472                          NONE                          NONE
#
#        participants_5_timeline_lane  participants_6_timeline_lane  \
# 0                            BOTTOM                        BOTTOM
# 1                               TOP                        BOTTOM
# 2                               TOP                        BOTTOM
# 3                            JUNGLE                        MIDDLE
# 4                            JUNGLE                        MIDDLE
# ...                             ...                           ...
# 29468                        MIDDLE                        JUNGLE
# 29469                          NONE                          NONE
# 29470                        JUNGLE                        BOTTOM
# 29471                           TOP                           TOP
# 29472                          NONE                          NONE
#
#        participants_7_timeline_lane  participants_8_timeline_lane  \
# 0                            MIDDLE                        JUNGLE
# 1                            BOTTOM                        JUNGLE
# 2                            BOTTOM                        JUNGLE
# 3                               TOP                        BOTTOM
# 4                               TOP                        BOTTOM
# ...                             ...                           ...
# 29468                        BOTTOM                        BOTTOM
# 29469                          NONE                          NONE
# 29470                           TOP                        MIDDLE
# 29471                        BOTTOM                        JUNGLE
# 29472                          NONE                          NONE
#
#        participants_9_timeline_lane
# 0                               TOP
# 1                            MIDDLE
# 2                               TOP
# 3                            BOTTOM
# 4                            BOTTOM
# ...                             ...
# 29468                        MIDDLE
# 29469                          NONE
# 29470                        BOTTOM
# 29471                        BOTTOM
# 29472                          NONE
#
# [29473 rows x 32 columns]

# %% [markdown]
# # fit

# %%
#results = smf.logit('teams_0_win ~ participantIdentities_1_player_accountId', data=df).fit()
#results.summary()
