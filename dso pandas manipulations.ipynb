# %%
#imports

# %matplotlib inline
import pandas as pd
import numpy as np
import time
import requests
import bs4
import json
from flatten_json import flatten

# %%
df = pd.read_csv('out.csv')
# Out:
# C:\Users\derek\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (98,99,100,101,214,215,216,217,330,331,332,333,446,447,448,449,562,563,564,565,678,679,680,681,794,795,796,797,910,911,912,913,1026,1027,1028,1029,1142,1143,1144,1145) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df[df['gameMode'] == "CLASSIC"]

# %%
# drop if one distinct value

for col in df.columns:
    if len(df[col].unique())==1:
        df = df.drop(col,axis=1)

# %%
# drop if null values are more than 25% of column

for col in df.columns:
    if (np.mean(df[col]!=df[col]) > .25):
        df = df.drop(col,axis=1)

# %%
df
# Out:
#            gameId   gameCreation  gameDuration  queueId     gameVersion  \
# 2      3425927177  1589811429884          1548      420  10.10.320.3039
# 3      3463315468  1592285561264          1499      420  10.12.324.5925
# 4      3490775054  1594487307024          2300      420  10.14.327.8505
# 5      3449782290  1591330333433          1413      420  10.11.322.2991
# 6      3482451986  1593821192664          1608      420  10.13.326.4870
# ...           ...            ...           ...      ...             ...
# 10440  3498213341  1595039589051          2049      440  10.14.327.8505
# 10441  3467476962  1592622681350          2291      420  10.12.325.6222
# 10442  3467968483  1592676623027          2244      420  10.12.325.6222
# 10443  3486023676  1594134989711          1360      420  10.13.326.4870
# 10444  3471409150  1592941466435          1484      420  10.12.325.6222
#
#       teams_0_win  teams_0_firstBlood  teams_0_firstTower  \
# 2             Win                True                True
# 3            Fail               False               False
# 4            Fail               False                True
# 5            Fail                True               False
# 6             Win                True               False
# ...           ...                 ...                 ...
# 10440         Win               False               False
# 10441         Win               False               False
# 10442         Win                True                True
# 10443         Win               False                True
# 10444        Fail               False                True
#
#        teams_0_firstInhibitor  teams_0_firstBaron  ...  \
# 2                        True                True  ...
# 3                       False               False  ...
# 4                       False                True  ...
# 5                       False               False  ...
# 6                        True                True  ...
# ...                       ...                 ...  ...
# 10440                    True                True  ...
# 10441                   False                True  ...
# 10442                    True               False  ...
# 10443                    True               False  ...
# 10444                   False               False  ...
#
#        participants_7_stats_wardsPlaced  participants_7_stats_wardsKilled  \
# 2                                   8.0                               2.0
# 3                                  21.0                               6.0
# 4                                   6.0                               5.0
# 5                                  10.0                               2.0
# 6                                   8.0                               2.0
# ...                                 ...                               ...
# 10440                              27.0                               5.0
# 10441                              45.0                              19.0
# 10442                              17.0                               4.0
# 10443                               7.0                              11.0
# 10444                               9.0                               6.0
#
#        participants_8_stats_neutralMinionsKilledTeamJungle  \
# 2                                                   92.0
# 3                                                   93.0
# 4                                                  102.0
# 5                                                    0.0
# 6                                                    4.0
# ...                                                  ...
# 10440                                               70.0
# 10441                                               36.0
# 10442                                               28.0
# 10443                                                0.0
# 10444                                              101.0
#
#        participants_8_stats_neutralMinionsKilledEnemyJungle  \
# 2                                                    0.0
# 3                                                   16.0
# 4                                                    3.0
# 5                                                    0.0
# 6                                                    0.0
# ...                                                  ...
# 10440                                               14.0
# 10441                                                8.0
# 10442                                                2.0
# 10443                                                0.0
# 10444                                               12.0
#
#        participants_8_stats_wardsPlaced  participants_8_stats_wardsKilled  \
# 2                                   3.0                               3.0
# 3                                   2.0                               5.0
# 4                                   6.0                              18.0
# 5                                  26.0                               4.0
# 6                                   8.0                               0.0
# ...                                 ...                               ...
# 10440                               6.0                               5.0
# 10441                              18.0                              11.0
# 10442                              12.0                               7.0
# 10443                               7.0                               0.0
# 10444                               5.0                               4.0
#
#        participants_9_stats_neutralMinionsKilledTeamJungle  \
# 2                                                    1.0
# 3                                                    0.0
# 4                                                   29.0
# 5                                                    0.0
# 6                                                    0.0
# ...                                                  ...
# 10440                                               20.0
# 10441                                                4.0
# 10442                                              122.0
# 10443                                                0.0
# 10444                                                9.0
#
#       participants_9_stats_neutralMinionsKilledEnemyJungle  \
# 2                                                    0.0
# 3                                                    4.0
# 4                                                    1.0
# 5                                                    0.0
# 6                                                    0.0
# ...                                                  ...
# 10440                                                0.0
# 10441                                                0.0
# 10442                                                3.0
# 10443                                                0.0
# 10444                                                0.0
#
#        participants_9_stats_wardsPlaced  participants_9_stats_wardsKilled
# 2                                   9.0                               0.0
# 3                                   3.0                               5.0
# 4                                  13.0                               8.0
# 5                                   9.0                               7.0
# 6                                  20.0                               5.0
# ...                                 ...                               ...
# 10440                               5.0                              10.0
# 10441                              17.0                               3.0
# 10442                              14.0                              10.0
# 10443                              17.0                               3.0
# 10444                               9.0                               2.0
#
# [8372 rows x 1143 columns]
